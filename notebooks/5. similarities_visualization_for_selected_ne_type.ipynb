# %%
import copy
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_hub as hub
import deeppavlov
from deeppavlov.dataset_readers.ontonotes_reader import OntonotesReader
from deeppavlov.models.preprocessors.capitalization import CapitalizationPreprocessor
from deeppavlov.models.embedders.glove_embedder import GloVeEmbedder
# Out:
# /home/kostrovskiy/prog/AI/NLP/DeepPavlov/env/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/kostrovskiy/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/kostrovskiy/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package perluniprops to
# [nltk_data]     /home/kostrovskiy/nltk_data...
# [nltk_data]   Package perluniprops is already up-to-date!
# [nltk_data] Downloading package nonbreaking_prefixes to
# [nltk_data]     /home/kostrovskiy/nltk_data...
# [nltk_data]   Package nonbreaking_prefixes is already up-to-date!
# 2018-08-14 17:26:40.506 DEBUG in 'gensim.models.doc2vec'['doc2vec'] at line 73: Fast version of gensim.models.doc2vec is being used
# 2018-08-14 17:26:40.513 INFO in 'summa.preprocessing.cleaner'['textcleaner'] at line 20: 'pattern' package not found; tag filters are not available for English
# 2018-08-14 17:26:47.897 DEBUG in 'matplotlib.backends'['__init__'] at line 90: backend module://ipykernel.pylab.backend_inline version unknown

# %% [markdown]
# ### Utility functions

# %%
def getNeTagMainPart(tag:str):
    return tag[2:] if tag != 'O' else tag

def tags2binary(tags, symb=True, types:list=None):
    tags = copy.deepcopy(tags)
    for seq in tags:
        for i in range(len(seq)):
            ne = False
            if seq[i] != 'O':
                ne = True
            if types and (getNeTagMainPart(seq[i]) not in types):
                ne = False
            if symb:
                seq[i] = 'T' if ne else 'O'
            else:
                seq[i] = 1 if ne else 0
#     print(np.sum(np.array([1 if t == 1 else 0 for seq in tags for t in seq])))
    return tags

def to_lower_case(tokens:list):
    tokens_lower = []
    for seq in tokens:
        tokens_lower.append([])
        for token in seq:
            tokens_lower[-1].append(token.lower())
    return tokens_lower

def get_tokens_len(tokens):
    if isinstance(tokens[0], str):
        tokens = [tokens]
    return [len(seq) for seq in tokens]

def add_padding(tokens:list):
    if isinstance(tokens[0], str):
        return tokens, len(tokens)
    elif isinstance(tokens[0], list):
        tokens = copy.deepcopy(tokens)
        max_len = 0
        for seq in tokens:
            if len(seq) > max_len:
                max_len = len(seq)
        for seq in tokens:
            i = len(seq)
            while i < max_len:
                seq.append('')
                i += 1
        return tokens
    else:
        raise Exception('tokens should be either list of strings or list of lists of strings')
        
def flatten_list(ar:list):
    flat = []
    for sublist in ar:
        flat += sublist
    return flat

def select_list_elements(ar:list, indices:list):
    return [ar[i] for i in indices]

# %% [markdown]
# ### Read data

# %%
reader = OntonotesReader()
dataset = reader.read(data_path='data/')
print(dataset.keys())
print('Num of train sentences: {}'.format(len(dataset['train'])))
print('Num of valid sentences: {}'.format(len(dataset['valid'])))
print('Num of test sentences: {}'.format(len(dataset['test'])))
print(dataset['train'][50:60])
# Out:
# dict_keys(['train', 'valid', 'test'])
# Num of train sentences: 75187
# Num of valid sentences: 9603
# Num of test sentences: 9479
# [(['Actions', 'had', 'to', 'be', 'taken', 'to', 'break', 'through', 'the', 'blockade', '.'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']), (['On', 'a', 'night', 'in', 'late', 'July', '1940', ',', 'the', 'atmosphere', 'in', 'Zhuanbi', 'Village', 'in', 'Shaanxi', 'was', 'unusual', '.'], ['O', 'B-DATE', 'I-DATE', 'I-DATE', 'I-DATE', 'I-DATE', 'I-DATE', 'O', 'O', 'O', 'O', 'B-GPE', 'I-GPE', 'O', 'B-GPE', 'O', 'O', 'O']), (['Villager', 'Xiao', 'Jianghe', 'has', 'a', 'vivid', 'memory', 'of', 'this', 'piece', 'of', 'history', '.'], ['O', 'B-PERSON', 'I-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']), (['On', 'that', 'dark', 'night', ',', 'everyone', 'was', 'sleeping', 'when', 'human', 'voices', 'and', 'neighing', 'horses', 'were', 'heard', 'within', 'the', 'village', '.'], ['O', 'B-TIME', 'I-TIME', 'I-TIME', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']), (['People', 'all', 'got', 'up', '.'], ['O', 'O', 'O', 'O', 'O']), (['Did', 'something', 'happen', '?'], ['O', 'O', 'O', 'O']), (['Some', 'folks', 'got', 'up', '.'], ['O', 'O', 'O', 'O', 'O']), (['Opening', 'the', 'street', 'gate', ',', 'they', 'saw', 'a', 'soldier', 'standing', 'by', 'the', 'gate', '.'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']), (['Folks', ',', 'go', 'back', ',', 'go', 'back', ',', 'nothing', 'is', 'wrong', '.'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']), (['Our', 'troops', 'are', 'just', 'going', 'to', 'stay', 'here', 'for', 'the', 'night', '.'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'])]

# %% [markdown]
# ### Select sentences with chosen NE types only

# %%
def filter_data_by_ne_type(data:list, ne_types:list, tags2binary=False):
    if ne_types == None or len(ne_types) == 0:
        return data
    data_filtered = []
    for tokens,tags in data:
        contains_all = True
        tags_norm = [getNeTagMainPart(t) for t in tags]
        for ne_type in ne_types:
            if not ne_type in tags_norm:
                contains_all = False
                break
        if contains_all:
            if tags2binary:
                tags = ['T' if t in ne_types else 'O' for t in tags_norm]
            data_filtered.append((tokens,tags))
    return data_filtered

# %%
NE_TYPES = ['PERSON']
# NE_TYPES = ['GPE']
for dataset_type in ['train', 'valid', 'test']:
    dataset[dataset_type] = filter_data_by_ne_type(dataset[dataset_type], NE_TYPES, tags2binary=True)
    print('Num of {} sentences: {}'.format(dataset_type, len(dataset[dataset_type])))
# Out:
# Num of train sentences: 12195
# Num of valid sentences: 1553
# Num of test sentences: 1573

# %% [markdown]
# ### Select few examples as support set

# %%
n_examples = 10
# np.random.seed(12)
indices = np.random.choice(len(dataset['train']), size=n_examples)
examples = [dataset['train'][i] for i in indices]
print(examples)
# Out:
# [(['Gambling', ',', 'however', ',', 'is', 'not', 'one', 'of', 'the', 'vices', 'Bennett', 'thinks', 'is', 'undermining', 'American', 'culture', '.'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'T', 'O', 'O', 'O', 'O', 'O', 'O']), (['So', 'John', 'McCall', 'was', 'doing', 'it', '%uh', 'last', 'week'], ['O', 'T', 'T', 'O', 'O', 'O', 'O', 'O', 'O']), (['Xiulian', 'Gu', ',', 'minister', 'of', 'the', 'Chemical', 'Industry', 'Ministry', ',', 'pointed', 'out', 'in', 'her', 'keynote', 'report', 'made', 'at', 'the', 'conference', 'that', 'although', 'China', "'s", 'chemical', 'industry', 'unflinchingly', 'faced', 'an', 'austere', 'situation', 'of', 'many', 'profit', 'decreasing', 'factors', 'and', 'slipping', 'benefits', ',', 'it', 'took', 'the', 'deepening', 'of', 'state', '-', 'owned', 'enterprise', 'reforms', 'as', 'a', 'breach', 'and', 'completed', 'the', 'whole', 'year', "'s", 'production', 'and', 'construction', 'tasks', 'relatively', 'well', '.'], ['T', 'T', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']), (['We', 'begin', 'where', 'he', 'began', 'this', 'journey', ',', 'in', 'Austin', ',', 'Texas', 'and', 'NBC', 'News', 'correspondent', 'Campbell', 'Brown', '.'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'T', 'T', 'O']), (['As', 'part', 'of', 'his', 'efforts', 'to', 'attract', 'more', 'Taiwanese', 'investors', 'to', 'do', 'business', 'in', 'Macau', ',', 'he', 'helped', 'introduce', 'President', 'Group', 'CEO', 'Kao', 'Chin', '-', 'yen', 'to', 'the', 'territory', ',', 'and', 'in', 'order', 'to', 'build', 'better', 'ties', 'with', 'the', 'mainland', 'Chinese', ',', 'he', 'helped', 'the', 'Xinhua', 'News', 'Agency', 'in', 'Macau', 'to', 'install', 'satellite', 'TV', '.'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'T', 'T', 'T', 'T', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']), (['``', 'You', "'re", 'not', 'going', 'to', 'make', 'it', 'in', 'a', '5', '%', 'bank', 'account', ',', "''", 'says', 'James', 'Riepe', ',', 'director', 'of', 'mutual', 'funds', 'at', 'T.', 'Rowe', 'Price', '.'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'T', 'T', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']), (['Albert', 'Fried', 'Jr.', ',', 'a', '59', '-', 'year', '-', 'old', 'director', 'and', 'holder', 'of', 'a', '9.5', '%', 'stake', 'in', 'the', 'company', ',', 'was', 'named', 'chairman', 'of', 'this', 'maker', 'of', 'products', 'for', 'the', 'construction', 'equipment', ',', 'material', 'handling', 'and', 'railroad', 'industries', '.'], ['T', 'T', 'T', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']), (['US', 'Defense', 'Secretary', 'William', 'Cohen', 'plans', 'to', 'travel', 'next', 'week', 'to', 'nine', 'Middle', 'Eastern', 'Gulf', 'states', 'for', 'meetings', 'with', 'regional', 'leaders', '.'], ['O', 'O', 'O', 'T', 'T', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']), (['Cross-strait', 'relations', ',', 'said', 'Chen', ',', 'were', 'just', 'one', 'of', 'many', 'issues', 'that', 'he', 'discussed', 'with', 'Lee', '.'], ['O', 'O', 'O', 'O', 'T', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'T', 'O']), (['"', 'Many', 'people', 'just', 'discuss', 'Floating', 'Life', 'from', 'the', 'perspective', 'of', 'immigration', ',', '"', 'Law', 'says', ',', '"', 'but', 'what', 'I', 'really', 'intended', 'to', 'show', 'was', 'how', 'fleeting', 'life', ...

# %% [markdown]
# ### Split tokens and tags

# %%
def split_tokens_tags(dataset: list):
    tokens = []
    tags = []
    for sample in dataset:
        tokens.append(sample[0])
        tags.append(sample[1])
    return tokens, tags

# %%
tokens_train,tags_train = split_tokens_tags(examples)
# print(tags_train)

# %%
def calc_data_props(tokens:list, tags:list):
    props = {}
    props['ne_types'] = {}
    tokens_flat = flatten_list(tokens)
    tags_flat = flatten_list(tags)
    ne_count = 0
    for tag in tags_flat:
        if tag != 'O':
            ne_count += 1
            tag_main = tag[2:]
            if props['ne_types'].get(tag_main) != None:
                props['ne_types'][tag_main] += 1
            else:
                props['ne_types'][tag_main] = 1
    props['sent_count'] = len(tokens)            
    props['tokens_count'] = len(tokens_flat)
    props['ne_count'] = ne_count
    props['ne_ratio'] = props['ne_count']/props['tokens_count']
    for k in props['ne_types'].keys():   
        props['ne_types'][k] /= ne_count
        
    return props
        
def print_data_props(props:dict):
    s = ''
    s += '#sentences = {}, '.format(props['sent_count'])
    s += '#tokens = {}, '.format(props['tokens_count'])
    s += '#ne = {}, '.format(props['ne_count'])
    s += '#ne / #tokens = {:.3f}, '.format(props['ne_ratio'])
    print(s)

# %%
print_data_props(calc_data_props(tokens_train,tags_train))
# Out:
# #sentences = 10, #tokens = 318, #ne = 21, #ne / #tokens = 0.066,

# %% [markdown]
# ### Elmo wrapper class

# %%
class ElmoEmbedder():
    def __init__(self):
        self.elmo = hub.Module("https://tfhub.dev/google/elmo/2", trainable=True)
        sess = tf.Session()
        sess.run(tf.global_variables_initializer())
        self.sess = sess

    def get_tokens_embeddings(self, tokens_input: list, tokens_length:list=None):
        if not tokens_length:
            if isinstance(tokens_input[0], list):
                tokens_length = [len(seq) for seq in tokens_input]
            else:
                tokens_length = len(tokens_input)
        embeddings = self.elmo(
                        inputs={
                            "tokens": tokens_input,
                            "sequence_len": tokens_length
                        },
                        signature="tokens",
                        as_dict=True)["elmo"]
        embeddings = self.sess.run([embeddings])
        return embeddings[0]

# %% [markdown]
# ### Main embedder

# %%
class CompositeEmbedder():
    def __init__(self, use_elmo=True, elmo_scale=1., cap_scale=1., use_cap_feat=False, use_glove=False, ):
        self.use_elmo = use_elmo
        self.elmo_scale = elmo_scale
        self.cap_scale = cap_scale
        self.use_cap_feat = use_cap_feat
        self.use_glove = use_glove
        if self.use_elmo:
            self.elmo = ElmoEmbedder()
        if self.use_cap_feat:
            self.cap_prep = CapitalizationPreprocessor()
        if self.use_glove:
            self.glove = GloVeEmbedder('embeddings/glove.6B/glove.6B.100d.txt', pad_zero=True)
        
    def embed(self, tokens: list):
        if isinstance(tokens[0], str):
            tokens = [tokens]
        # Get ELMo embeddings
        if self.use_elmo:
            tokens_input = add_padding(tokens)
            tokens_length = get_tokens_len(tokens)
            embeddings = self.elmo.get_tokens_embeddings(tokens_input, tokens_length)
            embeddings *= self.elmo_scale
            embed_size = embeddings.shape[-1]
#             print(embeddings.shape)
#             print(embed_size)

        # Use capitalization features
        if self.use_cap_feat:
#             print('Use capitalization features')
            cap_features = self.cap_prep(tokens)*self.cap_scale
    #         print(cap_features)
#             print(cap_features.shape)
            embeddings = np.concatenate((embeddings, cap_features), axis=2)
            embed_size = embeddings.shape[-1]
#             print(embeddings.shape)

        # Use GloVe embeddings
        if self.use_glove:
#             print('Use GloVe')
            
            glove_embed = self.glove(to_lower_case(tokens))
            glove_embed = np.array(glove_embed)
            if not self.use_elmo:
                embeddings = glove_embed
            else: 
                embeddings = np.concatenate((embeddings, glove_embed), axis=2)
            embed_size = embeddings.shape[-1]
#             print(embeddings.shape)
        
        return embeddings

# %% [markdown]
# ### Calculate similarity of token embedding vector to some prototype (centroid) or just support vector

# %%
def calc_sim(token_vec, support_vec)->dict:
    sim = {}
    sim['euc_dist'] = np.exp(-np.linalg.norm(token_vec - support_vec))
    sim['dot_prod'] = np.dot(token_vec, support_vec)
    sim['cosine'] = np.dot(token_vec, support_vec)/(np.linalg.norm(token_vec)*np.linalg.norm(support_vec)) if np.linalg.norm(support_vec) != 0 else 0
    return sim

# %%
def calc_sim_batch(tokens: list, embeddings: np.ndarray, support_vec: np.ndarray)->list:
    sim_list = []
    tokens_length = get_tokens_len(tokens)
    for i in range(len(tokens_length)):
        sim_list.append([])
        for j in range(tokens_length[i]):
            token_vec = embeddings[i,j,:]
            sim_list[i].append(calc_sim(token_vec, support_vec))
    return sim_list

# %%
def flatten_sim(sim_list):
    sims_flat = {'euc_dist': [], 'dot_prod': [], 'cosine': []}
    for i in range(len(sim_list)):
        for j in range(len(sim_list[i])):
            for sim_type in ['euc_dist', 'dot_prod', 'cosine']:
                sims_flat[sim_type].append(sim_list[i][j][sim_type])
    for sim_type in ['euc_dist', 'dot_prod', 'cosine']:
        sims_flat[sim_type] = np.array(sims_flat[sim_type])
    return sims_flat

# %% [markdown]
# ### Calculate centroid for named entities embedding vectors

# %%
def calc_ne_centroid_vec(tokens: list, tags: list, embeddings: np.ndarray=None, embedder: CompositeEmbedder=None):

    # Calculate embeddings
    if embedder != None:
        embeddings = embedder.embed(tokens)

    # Calculate average vector for ne-tags
    embed_size = embeddings.shape[-1]
    ne_prototype = np.zeros((embed_size,))
    tokens_length = get_tokens_len(tokens)
    tags_bin = np.array(flatten_list(tags2binary(tags, symb=False)))
#     print(tags_bin)
    n_ne_tags = np.sum(tags_bin == 1)
    embeddings_ne_flat = np.zeros((n_ne_tags, embed_size))
#     print(n_ne_tags)
#     n_ne_tags = 0
    k = 0
    for i in range(len(tokens_length)):
        for j in range(tokens_length[i]):
            if tags[i][j] == 'T' or tags[i][j] == 1:
                ne_prototype += embeddings[i,j,:].reshape((embed_size,))
                embeddings_ne_flat[k,:] = embeddings[i,j,:]
                k += 1
#                 n_ne_tags += 1
    if n_ne_tags != 0:
        ne_prototype /= n_ne_tags
    print('ne mean vector: {}'.format(ne_prototype))
    
    # Calculate similarities
    sim_list = calc_sim_batch(tokens, embeddings, ne_prototype)

    return ne_prototype, sim_list, embeddings, embeddings_ne_flat

# %% [markdown]
# ### Calculate similarities of some test tokens to NE prototype

# %%
def calc_sim_to_ne_prototype(tokens: list, ne_prototype: np.ndarray, embeddings: np.ndarray=None, embedder: CompositeEmbedder=None):
    if isinstance(tokens[0], str):
        tokens = [tokens]
    
    tokens_length = get_tokens_len(tokens)
    
    # Calculate embeddings
    if embedder != None:
        embeddings = embedder.embed(tokens)
    
    # Calculate similarities
    sim_list = calc_sim_batch(tokens, embeddings, ne_prototype)
    
    return sim_list, embeddings

# %%
def calc_sim_to_ne_nearest(tokens: list, ne_support_embeddings: np.ndarray, embeddings: np.ndarray=None, embedder: CompositeEmbedder=None):
    if isinstance(tokens[0], str):
        tokens = [tokens]
    
    tokens_length = get_tokens_len(tokens)
    
    # Calculate embeddings
    if embedder != None:
        embeddings = embedder.embed(tokens)
    
    # Calculate similarities
    n_supports = ne_support_embeddings.shape[0]
    sim_list = []
    tokens_length = get_tokens_len(tokens)
    for i in range(len(tokens_length)):
        sim_list.append([])
        for j in range(tokens_length[i]):
            token_vec = embeddings[i,j,:]
            sim_token_list = {'euc_dist': [], 'dot_prod': [], 'cosine': []}
            for k in range(n_supports):
                sim = calc_sim(token_vec, ne_support_embeddings[k, :])
                for sim_type in ['euc_dist', 'dot_prod', 'cosine']:
                    sim_token_list[sim_type].append(sim[sim_type])
            sim_list[i].append({'euc_dist': np.min(np.array(sim_token_list['euc_dist'])), 
                                'dot_prod': np.max(np.array(sim_token_list['dot_prod'])), 
                                'cosine': np.max(np.array(sim_token_list['cosine']))})
            
    return sim_list, embeddings

# %% [markdown]
# ### Embedder initialization

# %%
embedder = CompositeEmbedder(use_elmo=True, elmo_scale=1, cap_scale=1, use_cap_feat=True, use_glove=True)
# Out:
# INFO:tensorflow:Using /tmp/tfhub_modules to cache modules.
# 2018-08-14 17:26:53.270 INFO in 'tensorflow'['tf_logging'] at line 160: Using /tmp/tfhub_modules to cache modules.
# INFO:tensorflow:Initialize variable module/aggregation/scaling:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with aggregation/scaling
# 2018-08-14 17:26:53.853 INFO in 'tensorflow'['tf_logging'] at line 116: Initialize variable module/aggregation/scaling:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with aggregation/scaling
# INFO:tensorflow:Initialize variable module/aggregation/weights:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with aggregation/weights
# 2018-08-14 17:26:53.860 INFO in 'tensorflow'['tf_logging'] at line 116: Initialize variable module/aggregation/weights:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with aggregation/weights
# INFO:tensorflow:Initialize variable module/bilm/CNN/W_cnn_0:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/CNN/W_cnn_0
# 2018-08-14 17:26:53.868 INFO in 'tensorflow'['tf_logging'] at line 116: Initialize variable module/bilm/CNN/W_cnn_0:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/CNN/W_cnn_0
# INFO:tensorflow:Initialize variable module/bilm/CNN/W_cnn_1:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/CNN/W_cnn_1
# 2018-08-14 17:26:53.874 INFO in 'tensorflow'['tf_logging'] at line 116: Initialize variable module/bilm/CNN/W_cnn_1:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/CNN/W_cnn_1
# INFO:tensorflow:Initialize variable module/bilm/CNN/W_cnn_2:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/CNN/W_cnn_2
# 2018-08-14 17:26:53.880 INFO in 'tensorflow'['tf_logging'] at line 116: Initialize variable module/bilm/CNN/W_cnn_2:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/CNN/W_cnn_2
# INFO:tensorflow:Initialize variable module/bilm/CNN/W_cnn_3:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/CNN/W_cnn_3
# 2018-08-14 17:26:53.888 INFO in 'tensorflow'['tf_logging'] at line 116: Initialize variable module/bilm/CNN/W_cnn_3:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/CNN/W_cnn_3
# INFO:tensorflow:Initialize variable module/bilm/CNN/W_cnn_4:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/CNN/W_cnn_4
# 2018-08-14 17:26:53.894 INFO in 'tensorflow'['tf_logging'] at line 116: Initialize variable module/bilm/CNN/W_cnn_4:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/CNN/W_cnn_4
# INFO:tensorflow:Initialize variable module/bilm/CNN/W_cnn_5:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/CNN/W_cnn_5
# 2018-08-14 17:26:53.901 INFO in 'tensorflow'['tf_logging'] at line 116: Initialize variable module/bilm/CNN/W_cnn_5:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/CNN/W_cnn_5
# INFO:tensorflow:Initialize variable module/bilm/CNN/W_cnn_6:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/CNN/W_cnn_6
# 2018-08-14 17:26:53.907 INFO in 'tensorflow'['tf_logging'] at line 116: Initialize variable module/bilm/CNN/W_cnn_6:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/CNN/W_cnn_6
# INFO:tensorflow:Initialize variable module/bilm/CNN/b_cnn_0:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/CNN/b_cnn_0
# 2018-08-14 17:26:53.914 INFO in 'tensorflow'['tf_logging'] at line 116: Initialize variable module/bilm/CNN/b_cnn_0:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/CNN/b_cnn_0
# INFO:tensorflow:Initialize variable module/bilm/CNN/b_cnn_1:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/CNN/b_cnn_1
# 2018-08-14 17:26:53.921 INFO in 'tensorflow'['tf_logging'] at line 116: Initialize variable module/bilm/CNN/b_cnn_1:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/CNN/b_cnn_1
# INFO:tensorflow:Initialize variable module/bilm/CNN/b_cnn_2:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/CNN/b_cnn_2
# 2018-08-14 17:26:53.929 INFO in 'tensorflow'['tf_logging'] at line 116: Initialize variable module/bilm/CNN/b_cnn_2:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/CNN/b_cnn_2
# INFO:tensorflow:Initialize variable module/bilm/CNN/b_cnn_3:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/CNN/b_cnn_3
# 2018-08-14 17:26:53.934 INFO in 'tensorflow'['tf_logging'] at line 116: Initialize variable module/bilm/CNN/b_cnn_3:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/CNN/b_cnn_3
# INFO:tensorflow:Initialize variable module/bilm/CNN/b_cnn_4:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/CNN/b_cnn_4
# 2018-08-14 17:26:53.942 INFO in 'tensorflow'['tf_logging'] at line 116: Initialize variable module/bilm/CNN/b_cnn_4:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/CNN/b_cnn_4
# INFO:tensorflow:Initialize variable module/bilm/CNN/b_cnn_5:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/CNN/b_cnn_5
# 2018-08-14 17:26:53.948 INFO in 'tensorflow'['tf_logging'] at line 116: Initialize variable module/bilm/CNN/b_cnn_5:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/CNN/b_cnn_5
# INFO:tensorflow:Initialize variable module/bilm/CNN/b_cnn_6:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/CNN/b_cnn_6
# 2018-08-14 17:26:53.954 INFO in 'tensorflow'['tf_logging'] at line 116: Initialize variable module/bilm/CNN/b_cnn_6:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/CNN/b_cnn_6
# INFO:tensorflow:Initialize variable module/bilm/CNN_high_0/W_carry:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/CNN_high_0/W_carry
# 2018-08-14 17:26:53.962 INFO in 'tensorflow'['tf_logging'] at line 116: Initialize variable module/bilm/CNN_high_0/W_carry:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/CNN_high_0/W_carry
# INFO:tensorflow:Initialize variable module/bilm/CNN_high_0/W_transform:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/CNN_high_0/W_transform
# 2018-08-14 17:26:53.969 INFO in 'tensorflow'['tf_logging'] at line 116: Initialize variable module/bilm/CNN_high_0/W_transform:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/CNN_high_0/W_transform
# INFO:tensorflow:Initialize variable module/bilm/CNN_high_0/b_carry:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/CNN_high_0/b_carry
# 2018-08-14 17:26:53.974 INFO in 'tensorflow'['tf_logging'] at line 116: Initialize variable module/bilm/CNN_high_0/b_carry:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/CNN_high_0/b_carry
# INFO:tensorflow:Initialize variable module/bilm/CNN_high_0/b_transform:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/CNN_high_0/b_transform
# 2018-08-14 17:26:53.982 INFO in 'tensorflow'['tf_logging'] at line 116: Initialize variable module/bilm/CNN_high_0/b_transform:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/CNN_high_0/b_transform
# INFO:tensorflow:Initialize variable module/bilm/CNN_high_1/W_carry:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/CNN_high_1/W_carry
# 2018-08-14 17:26:53.990 INFO in 'tensorflow'['tf_logging'] at line 116: Initialize variable module/bilm/CNN_high_1/W_carry:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/CNN_high_1/W_carry
# INFO:tensorflow:Initialize variable module/bilm/CNN_high_1/W_transform:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/CNN_high_1/W_transform
# 2018-08-14 17:26:53.999 INFO in 'tensorflow'['tf_logging'] at line 116: Initialize variable module/bilm/CNN_high_1/W_transform:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/CNN_high_1/W_transform
# INFO:tensorflow:Initialize variable module/bilm/CNN_high_1/b_carry:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/CNN_high_1/b_carry
# 2018-08-14 17:26:54.7 INFO in 'tensorflow'['tf_logging'] at line 116: Initialize variable module/bilm/CNN_high_1/b_carry:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/CNN_high_1/b_carry
# INFO:tensorflow:Initialize variable module/bilm/CNN_high_1/b_transform:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/CNN_high_1/b_transform
# 2018-08-14 17:26:54.13 INFO in 'tensorflow'['tf_logging'] at line 116: Initialize variable module/bilm/CNN_high_1/b_transform:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/CNN_high_1/b_transform
# INFO:tensorflow:Initialize variable module/bilm/CNN_proj/W_proj:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/CNN_proj/W_proj
# 2018-08-14 17:26:54.20 INFO in 'tensorflow'['tf_logging'] at line 116: Initialize variable module/bilm/CNN_proj/W_proj:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/CNN_proj/W_proj
# INFO:tensorflow:Initialize variable module/bilm/CNN_proj/b_proj:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/CNN_proj/b_proj
# 2018-08-14 17:26:54.25 INFO in 'tensorflow'['tf_logging'] at line 116: Initialize variable module/bilm/CNN_proj/b_proj:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/CNN_proj/b_proj
# INFO:tensorflow:Initialize variable module/bilm/RNN_0/RNN/MultiRNNCell/Cell0/rnn/lstm_cell/bias:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/RNN_0/RNN/MultiRNNCell/Cell0/rnn/lstm_cell/bias
# 2018-08-14 17:26:54.31 INFO in 'tensorflow'['tf_logging'] at line 116: Initialize variable module/bilm/RNN_0/RNN/MultiRNNCell/Cell0/rnn/lstm_cell/bias:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/RNN_0/RNN/MultiRNNCell/Cell0/rnn/lstm_cell/bias
# INFO:tensorflow:Initialize variable module/bilm/RNN_0/RNN/MultiRNNCell/Cell0/rnn/lstm_cell/kernel:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/RNN_0/RNN/MultiRNNCell/Cell0/rnn/lstm_cell/kernel
# 2018-08-14 17:26:54.38 INFO in 'tensorflow'['tf_logging'] at line 116: Initialize variable module/bilm/RNN_0/RNN/MultiRNNCell/Cell0/rnn/lstm_cell/kernel:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/RNN_0/RNN/MultiRNNCell/Cell0/rnn/lstm_cell/kernel
# INFO:tensorflow:Initialize variable module/bilm/RNN_0/RNN/MultiRNNCell/Cell0/rnn/lstm_cell/projection/kernel:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/RNN_0/RNN/MultiRNNCell/Cell0/rnn/lstm_cell/projection/kernel
# 2018-08-14 17:26:54.44 INFO in 'tensorflow'['tf_logging'] at line 116: Initialize variable module/bilm/RNN_0/RNN/MultiRNNCell/Cell0/rnn/lstm_cell/projection/kernel:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/RNN_0/RNN/MultiRNNCell/Cell0/rnn/lstm_cell/projection/kernel
# INFO:tensorflow:Initialize variable module/bilm/RNN_0/RNN/MultiRNNCell/Cell1/rnn/lstm_cell/bias:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/RNN_0/RNN/MultiRNNCell/Cell1/rnn/lstm_cell/bias
# 2018-08-14 17:26:54.50 INFO in 'tensorflow'['tf_logging'] at line 116: Initialize variable module/bilm/RNN_0/RNN/MultiRNNCell/Cell1/rnn/lstm_cell/bias:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/RNN_0/RNN/MultiRNNCell/Cell1/rnn/lstm_cell/bias
# INFO:tensorflow:Initialize variable module/bilm/RNN_0/RNN/MultiRNNCell/Cell1/rnn/lstm_cell/kernel:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/RNN_0/RNN/MultiRNNCell/Cell1/rnn/lstm_cell/kernel
# 2018-08-14 17:26:54.57 INFO in 'tensorflow'['tf_logging'] at line 116: Initialize variable module/bilm/RNN_0/RNN/MultiRNNCell/Cell1/rnn/lstm_cell/kernel:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/RNN_0/RNN/MultiRNNCell/Cell1/rnn/lstm_cell/kernel
# INFO:tensorflow:Initialize variable module/bilm/RNN_0/RNN/MultiRNNCell/Cell1/rnn/lstm_cell/projection/kernel:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/RNN_0/RNN/MultiRNNCell/Cell1/rnn/lstm_cell/projection/kernel
# 2018-08-14 17:26:54.65 INFO in 'tensorflow'['tf_logging'] at line 116: Initialize variable module/bilm/RNN_0/RNN/MultiRNNCell/Cell1/rnn/lstm_cell/projection/kernel:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/RNN_0/RNN/MultiRNNCell/Cell1/rnn/lstm_cell/projection/kernel
# INFO:tensorflow:Initialize variable module/bilm/RNN_1/RNN/MultiRNNCell/Cell0/rnn/lstm_cell/bias:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/RNN_1/RNN/MultiRNNCell/Cell0/rnn/lstm_cell/bias
# 2018-08-14 17:26:54.73 INFO in 'tensorflow'['tf_logging'] at line 116: Initialize variable module/bilm/RNN_1/RNN/MultiRNNCell/Cell0/rnn/lstm_cell/bias:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/RNN_1/RNN/MultiRNNCell/Cell0/rnn/lstm_cell/bias
# INFO:tensorflow:Initialize variable module/bilm/RNN_1/RNN/MultiRNNCell/Cell0/rnn/lstm_cell/kernel:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/RNN_1/RNN/MultiRNNCell/Cell0/rnn/lstm_cell/kernel
# 2018-08-14 17:26:54.81 INFO in 'tensorflow'['tf_logging'] at line 116: Initialize variable module/bilm/RNN_1/RNN/MultiRNNCell/Cell0/rnn/lstm_cell/kernel:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/RNN_1/RNN/MultiRNNCell/Cell0/rnn/lstm_cell/kernel
# INFO:tensorflow:Initialize variable module/bilm/RNN_1/RNN/MultiRNNCell/Cell0/rnn/lstm_cell/projection/kernel:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/RNN_1/RNN/MultiRNNCell/Cell0/rnn/lstm_cell/projection/kernel
# 2018-08-14 17:26:54.92 INFO in 'tensorflow'['tf_logging'] at line 116: Initialize variable module/bilm/RNN_1/RNN/MultiRNNCell/Cell0/rnn/lstm_cell/projection/kernel:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/RNN_1/RNN/MultiRNNCell/Cell0/rnn/lstm_cell/projection/kernel
# INFO:tensorflow:Initialize variable module/bilm/RNN_1/RNN/MultiRNNCell/Cell1/rnn/lstm_cell/bias:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/RNN_1/RNN/MultiRNNCell/Cell1/rnn/lstm_cell/bias
# 2018-08-14 17:26:54.101 INFO in 'tensorflow'['tf_logging'] at line 116: Initialize variable module/bilm/RNN_1/RNN/MultiRNNCell/Cell1/rnn/lstm_cell/bias:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/RNN_1/RNN/MultiRNNCell/Cell1/rnn/lstm_cell/bias
# INFO:tensorflow:Initialize variable module/bilm/RNN_1/RNN/MultiRNNCell/Cell1/rnn/lstm_cell/kernel:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/RNN_1/RNN/MultiRNNCell/Cell1/rnn/lstm_cell/kernel
# 2018-08-14 17:26:54.111 INFO in 'tensorflow'['tf_logging'] at line 116: Initialize variable module/bilm/RNN_1/RNN/MultiRNNCell/Cell1/rnn/lstm_cell/kernel:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/RNN_1/RNN/MultiRNNCell/Cell1/rnn/lstm_cell/kernel
# INFO:tensorflow:Initialize variable module/bilm/RNN_1/RNN/MultiRNNCell/Cell1/rnn/lstm_cell/projection/kernel:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/RNN_1/RNN/MultiRNNCell/Cell1/rnn/lstm_cell/projection/kernel
# 2018-08-14 17:26:54.119 INFO in 'tensorflow'['tf_logging'] at line 116: Initialize variable module/bilm/RNN_1/RNN/MultiRNNCell/Cell1/rnn/lstm_cell/projection/kernel:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/RNN_1/RNN/MultiRNNCell/Cell1/rnn/lstm_cell/projection/kernel
# INFO:tensorflow:Initialize variable module/bilm/char_embed:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/char_embed
# 2018-08-14 17:26:54.128 INFO in 'tensorflow'['tf_logging'] at line 116: Initialize variable module/bilm/char_embed:0 from checkpoint b'/tmp/tfhub_modules/9bb74bc86f9caffc8c47dd7b33ec4bb354d9602d/variables/variables' with bilm/char_embed
# 2018-08-14 17:26:54.516 INFO in 'deeppavlov.models.embedders.glove_embedder'['glove_embedder'] at line 60: [loading embeddings from `/home/kostrovskiy/prog/AI/NLP/DeepPavlov/download/embeddings/glove.6B/glove.6B.100d.txt`]
# 2018-08-14 17:26:54.517 INFO in 'gensim.models.keyedvectors'['keyedvectors'] at line 204: loading projection weights from /home/kostrovskiy/prog/AI/NLP/DeepPavlov/download/embeddings/glove.6B/glove.6B.100d.txt
# 2018-08-14 17:26:54.517 DEBUG in 'smart_open.smart_open_lib'['smart_open_lib'] at line 176: {'kw': {}, 'mode': 'rb', 'uri': '/home/kostrovskiy/prog/AI/NLP/DeepPavlov/download/embeddings/glove.6B/glove.6B.100d.txt'}
# 2018-08-14 17:27:24.619 INFO in 'gensim.models.keyedvectors'['keyedvectors'] at line 266: loaded (400000, 100) matrix from /home/kostrovskiy/prog/AI/NLP/DeepPavlov/download/embeddings/glove.6B/glove.6B.100d.txt

# %% [markdown]
# ### Calculate NE centroid for support examples

# %%
ne_prototype, _, embeddings_support, ne_support_embeddings = calc_ne_centroid_vec(tokens_train, tags_train, embedder=embedder)
print(ne_support_embeddings.shape)
# Out:
# ne mean vector: [-0.51034612 -0.08264052  0.15285881 ... -0.52949457  0.00990581
#  -0.26542243]
# (21, 1128)

# %% [markdown]
# ### Select some unlabeled examples from the test set and estimate similarity to a named entity for each token

# %%
n_test_sentences = 100
# np.random.seed(44)
indices_test = np.random.choice(len(dataset['test']), size=n_test_sentences)
test_sentences = select_list_elements(dataset['test'], indices_test)
tokens_test,tags_test = split_tokens_tags(test_sentences)
print_data_props(calc_data_props(tokens_test,tags_test))
# print(tokens_test)
# print(tags_test)
# Out:
# #sentences = 100, #tokens = 2676, #ne = 231, #ne / #tokens = 0.086,

# %%
sim_list_test = {}
sim_list_test['centroid'], embeddings_test = calc_sim_to_ne_prototype(tokens_test, ne_prototype, embedder=embedder)
sim_list_test['nearest'], _ = calc_sim_to_ne_nearest(tokens_test, ne_support_embeddings, embedder=embedder)

# %% [markdown]
# ### Group similarities with tokens

# %%
def zip_tokens_sim(tokens: list, sim_list: list, sim_type='cosine'):
    tokens_sim = []
    for i in range(len(tokens)):
        tokens_sim.append([])
        for j in range(len(tokens[i])):
            sim = sim_list[i][j][sim_type] if isinstance(sim_list[i][j], dict) else sim_list[i][j]
            tokens_sim[-1].append((tokens[i][j], sim))
    return tokens_sim

# %%
tokens_test_sim = {}
tokens_test_sim['centroid'] = zip_tokens_sim(tokens_test, sim_list_test['centroid'])
tokens_test_sim['nearest'] = zip_tokens_sim(tokens_test, sim_list_test['nearest'])

# %% [markdown]
# ### Print test sentences with NE similarities estimations

# %%
def decorate_ne_token(token, tag):
    if tag == 'T':
        token = '[[' + token + ']]'
    return token
def format_labeled_examples(tokens_input: list, tags_input: list):
    s = '+++++++++ Input examples +++++++++\n\n'
    for i in range(len(tokens_input)):
        for j in range(len(tokens_input[i])):
            s += decorate_ne_token(tokens_input[i][j], tags_input[i][j]) + ' '
        s += '\n\n'
    return s

# %%
def format_inference_results(tokens_sim: list):
    s = '+++++++++ Tests +++++++++\n\n'
    for seq in tokens_sim:
        for token, sim in seq:
            s += '{}[{:.3f}]'.format(token, sim)
            s += ' '
        s += '\n\n'
    return s

# %%
text = ''
text += format_labeled_examples(tokens_train, tags_train)
text += format_inference_results(tokens_test_sim['centroid'])
print(text)
# Out:
# +++++++++ Input examples +++++++++
#
# Gambling , however , is not one of the vices [[Bennett]] thinks is undermining American culture .
#
# So [[John]] [[McCall]] was doing it %uh last week
#
# [[Xiulian]] [[Gu]] , minister of the Chemical Industry Ministry , pointed out in her keynote report made at the conference that although China 's chemical industry unflinchingly faced an austere situation of many profit decreasing factors and slipping benefits , it took the deepening of state - owned enterprise reforms as a breach and completed the whole year 's production and construction tasks relatively well .
#
# We begin where he began this journey , in Austin , Texas and NBC News correspondent [[Campbell]] [[Brown]] .
#
# As part of his efforts to attract more Taiwanese investors to do business in Macau , he helped introduce President Group CEO [[Kao]] [[Chin]] [[-]] [[yen]] to the territory , and in order to build better ties with the mainland Chinese , he helped the Xinhua News Agency in Macau to install satellite TV .
#
# `` You 're not going to make it in a 5 % bank account , '' says [[James]] [[Riepe]] , director of mutual funds at T. Rowe Price .
#
# [[Albert]] [[Fried]] [[Jr.]] , a 59 - year - old director and holder of a 9.5 % stake in the company , was named chairman of this maker of products for the construction equipment , material handling and railroad industries .
#
# US Defense Secretary [[William]] [[Cohen]] plans to travel next week to nine Middle Eastern Gulf states for meetings with regional leaders .
#
# Cross-strait relations , said [[Chen]] , were just one of many issues that he discussed with [[Lee]] .
#
# " Many people just discuss Floating Life from the perspective of immigration , " [[Law]] says , " but what I really intended to show was how fleeting life is , and how people go about surviving in rootless societies . "
#
# +++++++++ Tests +++++++++
#
# The[0.279] singer[0.242] was[0.237] brother[0.265] Jermaine[0.284] ,[0.216] and[0.247] the[0.191] claims[0.177] based[0.178] on[0.170] the[0.193] projected[0.093] outline[0.115] for[0.159] his[0.184] abandoned[0.084] ``[0.213] tell[0.135] -[0.212] all[0.100] ''[0.214] family[0.177] story[0.189] .[0.193]
#
# As[0.267] Greg[0.402] Lefevre[0.418] reports[0.235] ,[0.245] many[0.179] stores[0.182] have[0.166] sold[0.111] out[0.168] of[0.127] the[0.158] game[0.160] even[0.164] before[0.178] its[0.107] release[0.152] .[0.186]
#
# Dr.[0.374] Johnsee[0.498] Lee[0.642] ,[0.295] who[0.346] as[0.234] well[0.234] as[0.220] heading[0.219] up[0.202] the[0.247] Biomedical[0.179] Engineering[0.202] Center[0.306] is[0.253] also[0.277] general[0.217] director[0.282] of[0.192] Union[0.313] Chemical[0.283] Laboratories[0.264] ,[0.310] a[0.196] research[0.155] institute[0.213] under[0.167] the[0.221] ITRI[0.214] umbrella[0.144] ,[0.341] says[0.212] that[0.236] due[0.143] to[0.118] biochips[0.098] '[0.086] advantages[0.103] of[0.089] miniaturization[0.111] ,[0.153] parallelism[0.159] ,[0.127] speed[0.108] and[0.135] the[0.120] ability[0.113] to[0.112] reveal[0.083] the[0.143] "[0.132] big[0.090] picture[0.135] ,[0.192] "[0.208] they[0.207] have[0.156] a[0.110] very[0.101] wide[0.048] range[0.122] of[0.072] applications[0.098] .[0.193]
#
# Sen.[0.299] H.[0.336] Alexander[0.400] Smith[0.511] -LRB-[0.233] R[0.313] -[0.213] N.J.[0.289] -RRB-[0.224] ,[0.249] Buchman[0.415] 's[0.222] lieutenant[0.223] who[0.325] in[0.174] 1940[0.295] had[0.240] called[0.197] for[0.148] a[0.171] joint[0.074] world[0.107] dictatorship[0.201] of[0.088] the[0.199] United[0.214] States[0.260] ,[0.213] Britain[0.333] ,[0.201] and[0.158] Nazi[0.170] Germany[0.357] ,[0.334] brought[0.180] the[0.165] Fellowship[0.211] into[0.091] acceptance[0.104] in[0.167] Washington[0.364] .[0.210]
#
# NPR[0.310] 's[0.176] Rob[0.391] Gifford[0.473] reports[0.231] from[0.201] the[0.210] Chinese[0.252] capital[0.215] .[0.215]
#
# and[0.215] possibly[0.156] Karl[0.343] Rove[0.378] could[0.199] be[0.176] among[0.106] them[0.292] /.[0.180]
#
# and[0.243] when[0.216] she[0.321] gives[0.156] me[0.223] thumbs[0.180] down[0.219] Howie[0.373] I[0.310] have[0.197] to[0.174] put[0.179] it[0.184] in[0.154] a[0.133] ball[0.122] throw[0.184] it[0.235] in[0.168] the[0.138] circular[0.139] file[0.123] and[0.184] start[0.122] over[0.192] /.[0.184]
#
# Robert[0.499] White[0.531] ,[0.283] Canadian[0.276] Auto[0.202] Workers[0.230] union[0.185] president[0.279] ,[0.348] used[0.153] the[0.205] impending[0.077] Scarborough[0.258] shutdown[0.140] to[0.160] criticize[0.130] the[0.205] U.S.[0.211] -[0.227] Canada[0.331] free[0.145] trade[0.153] agreement[0.161] and[0.180] its[0.173] champion[0.166] ,[0.233] Prime[0.240] Minister[0.237] Brian[0.319] Mulroney[0.417] .[0.214]
#
# NPR[0.316] 's[0.175] Jerry[0.341] Hadden[0.361] reports[0.203] .[0.216]
#
# PCS[0.259] also[0.240] named[0.209] Rex[0.390] R.[0.391] Malson[0.468] ,[0.272] 57[0.299] ,[0.304] executive[0.234] vice[0.201] president[0.253] at[0.229] McKesson[0.360] ,[0.283] as[0.184] a[0.212] director[0.262] ,[0.270] filling[0.144] the[0.150] seat[0.137] vacated[0.143] by[0.189] Mr.[0.383] Field[0.314] .[0.217]
#
# The[0.257] truth[0.152] is[0.202] that[0.239] as[0.173] Howie[0.426] said[0.280] she[0.351] did[0.226] testify[0.191] /.[0.200]
#
# Chang[0.601] Der[0.427] -[0.335] chung[0.373] ,[0.280] an[0.270] associate[0.226] professor[0.285] in[0.206] the[0.247] Department[0.285] of[0.218] Living[0.255] Science[0.271] at[0.201] National[0.224] Open[0.205] University[0.320] who[0.364] worked[0.210] at[0.198] a[0.161] counseling[0.083] hotline[0.136] for[0.175] over[0.136] a[0.155] decade[0.221] ,[0.377] argues[0.210] that[0.208] any[0.128] step[0.115] in[0.137] the[0.129] right[0.099] direction[0.174] is[0.186] worthwhile[0.131] ,[0.230] no[0.143] matter[0.125] when[0.195] you[0.216] start[0.110] .[0.194]
#
# Well[0.326] not[0.198] only[0.204] is[0.181] that[0.180] false[0.073] and[0.209] President[0.339] Clinton[0.417] has[0.218] said[0.240] so[0.219] but[0.252] everybody[0.251] who[0.282] attended[0.222] the[0.190] meeting[0.205] not[0.199] including[0.176] Louis[0.404] Freeh[0.422] says[0.220] it[0.291] 's[0.214] false[0.093] /.[0.168]
#
# Richard[0.452] Chamberlain[0.503] dresses[0.159] as[0.153] a[0.182] ``[0.208] Mainland[0.303] haole[0.137] ,[0.263] ''[0.269] tucking[0.121] in[0.212] a[0.148] Hawaiian[0.168] shirt[0.162] and[0.188] rolling[0.133] up[0.139] its[0.120] long[0.124] sleeves[0.106] .[0.211]
#
# -LRB-[0.274] Teng[0.535] Sue[0.528] -[0.268] feng[0.290] /[0.166] photos[0.147] by[0.199] Jimmy[0.398] Lin[0.527] /[0.136] tr.[0.137] by[0.197] Christopher[0.441] MacDonald[0.462] -RRB-[0.212]
#
# Jackson[0.500] seems[0.128] to[0.156] be[0.157] of[0.111] this[0.143] type[0.159] .[0.217]
#
# The[0.261] reason[0.128] they[0.235] are[0.144] picking[0.129] that[0.181] particular[0.106] day[0.202] is[0.198] it[0.292] allows[0.097] ,[0.297] Brian[0.444] ,[0.229] enough[0.141] time[0.190] for[0.165] the[0.192] aggrieved[0.075] party[0.188] ,[0.244] the[0.183] losing[0.099] party[0.196] to[0.127] file[0.119] within[0.122] 10[0.179] days[0.173] a[0.144] contest[0.152] of[0.119] the[0.156] certification[0.112] and[0.195] that[0.240] still[0.161] allows[0.086] enough[0.119] time[0.166] for[0.154] the[0.157] contest[0.149] to[0.135] be[0.153] litigated[0.108] through[0.089] the[0.139] courts[0.158] primarily[0.185] the[0.162] circuit[0.171] court[0.191] and[0.156] back[0.134] to[0.122] the[0.173] Supreme[0.182] Court[0.237] if[0.137] necessary[0.153] and[0.195] still[0.148] meet[0.121] the[0.200] December[0.163] 12[0.213] deadline[0.127] for[0.144] the[0.152] Electoral[0.086] College[0.207] vote[0.174] here[0.271] .[0.191]
#
# Jerry[0.453] Shrieves[0.495] ,[0.266] UAW[0.213] local[0.216] president[0.303] ,[0.336] said[0.239] the[0.208] facility[0.204] was[0.194] asked[0.224] to[0.162] draw[0.107] up[0.131] plans[0.182] to[0.141] continue[0.125] working[0.154] as[0.121] a[0.168] ``[0.195] flex[0.070] plant[0.167] ,[0.219] ''[0.224] which[0.209] could[0.136] build[0.065] several[0.099] different[0.070] types[0.099] of[0.067] products[0.173] on[0.111] short[0.129] notice[0.123] to[0.131] satisfy[0.068] demand[0.155] .[0.208]
#
# Pat[0.407] Fitzgerald[0.531] /.[0.257]
#
# And[0.303] then[0.246] we[0.242] saw[0.212] Leo[0.390] and[0.269] Julie[0.377] at[0.191] Christmas[0.209] time[0.190] .[0.205]
#
# -LRB-[0.274] Teng[0.535] Sue[0.528] -[0.268] feng[0.290] /[0.166] photos[0.147] by[0.199] Jimmy[0.398] Lin[0.527] /[0.136] tr.[0.137] by[0.197] Christopher[0.441] MacDonald[0.462] -RRB-[0.212]
#
# ``[0.251] This[0.275] is[0.189] something[0.155] P&G[0.380] would[0.221] do[0.211] with[0.192] or[0.191] without[0.175] Kao[0.541] ,[0.286] ''[0.322] says[0.342] Mr.[0.437] Zurkuhlen[0.413] .[0.199]
#
# "[0.265] We[0.298] always[0.188] jokingly[0.153] refer[0.169] to[0.137] it[0.233] as[0.138] Fort[0.246] Pouchen[0.330] ,[0.216] "[0.298] says[0.300] Yeh[0.595] .[0.228]
#
# In[0.268] his[0.194] meeting[0.221] with[0.223] the[0.230] Uruguayan[0.230] guests[0.239] ,[0.299] Qichen[0.478] Qian[0.576] expressed[0.157] welcome[0.154] over[0.206] the[0.248] visit[0.219] by[0.231] vice[0.257] Foreign[0.266] Affairs[0.285] Minister[0.330] Kamyao[0.341] and[0.266] the[0.240] political[0.187] consultations[0.193] in[0.135] progress[0.152] .[0.234]
#
# That[0.319] shows[0.159] how[0.139] far[0.183] Ted[0.319] Turner[0.403] 's[0.171] Cable[0.246] News[0.229] Network[0.205] has[0.182] come[0.162] since[0.171] its[0.117] birth[0.141] nine[0.156] years[0.188] ago[0.248] ,[0.257] when[0.190] it[0.273] was[0.216] considered[0.137] the[0.128] laughingstock[0.058] of[0.097] television[0.164] news[0.158] .[0.196]
#
# Ever[0.221] the[0.166] rock[0.135] ,[0.221] Sharon[0.420] faced[0.128] cancer[0.181] head[0.205] on[0.179] .[0.197]
#
# Saddam[0.366] Hussein[0.435] -LRB-[0.196] in[0.143] language[0.141] beaming[0.174] with[0.133] pride[0.163] and[0.152] arrogance[0.166] -RRB-[0.221] I[0.314] want[0.123] you[0.242] first[0.223] of[0.102] all[0.167] ..[0.138] to[0.161] set[0.143] me[0.189] a[0.109] timetable[0.119] for[0.145] the[0.145] withdrawal[0.122] from[0.106] Iraq[0.251] that[0.216] your[0.148] government[0.239] will[0.166] commit[0.122] itself[0.150] to[0.140] it[0.250] in[0.127] front[0.127] of[0.125] the[0.136] world[0.150] ,[0.213] and[0.181] for[0.155] you[0.228] to[0.142] begin[0.136] the[0.145] withdrawal[0.110] operation[0.137] immediately[0.206] .[0.202]
#
# Rumsfeld[0.431] :[0.191] Stop[0.214] from[0.125] this[0.198] drivel[0.151] ,[0.254] I[0.326] am[0.161] offering[0.138] you[0.241] ...[0.172]
#
# However[0.284] ,[0.221] Pan[0.365] points[0.167] out[0.165] that[0.226] because[0.152] of[0.141] the[0.169] difficulties[0.141] in[0.115] substantially[0.103] reducing[0.089] the[0.142] time[0.130] needed[0.147] for[0.123] sample[0.075] preparation[0.156] ,[0.209] the[0.210] usefulness[0.086] of[0.091] such[0.145] a[0.169] fever[0.150] chip[0.199] is[0.139] still[0.138] limited[0.176] ,[0.232] so[0.146] that[0.197] it[0.262] can[0.146] not[0.153] yet[0.144] be[0.150] widely[0.117] promoted[0.181] .[0.196]
#
# "[0.294] We[0.312] do[0.184] n't[0.214] take[0.152] much[0.176] of[0.152] a[0.181] break[0.184] for[0.178] the[0.205] Chinese[0.292] New[0.240] Year[0.267] 's[0.260] holidays[0.184] ,[0.251] "[0.316] says[0.322] Andrew[0.559] Yeh[0.599] ,[0.352] chairman[0.367] of[0.270] Dongguan[0.383] 's[0.248] Powin[0.369] Electric[0.279] ,[0.274] which[0.279] makes[0.176] cable[0.150] for[0.154] the[0.182] telecoms[0.151] industry[0.248] .[0.223]
#
# Gao[0.560] Xingjian[0.476] arrived[0.245] in[0.213] Stockholm[0.306] this[0.207] week[0.246] and[0.385] when[0.297] he[0.357] leaves[0.229] the[0.274] Chinese[0.288] born[0.165] writer[0.278] will[0.261] have[0.236] something[0.170] extra[0.150] in[0.155] his[0.197] suitcase[0.143] ,[0.286] the[0.227] Nobel[0.218] Prize[0.216] for[0.188] Literature[0.257] .[0.220]
#
# I[0.334] am[0.199] Tony[0.428] Kahn[0.548] .[0.215]
#
# "[0.264] Because[0.254] this[0.204] area[0.169] is[0.135] a[0.130] patents[0.076] minefield[0.125] ,[0.219] it[0.292] 's[0.179] impossible[0.114] to[0.153] create[0.108] a[0.149] product[0.125] which[0.206] from[0.120] start[0.156] to[0.094] finish[0.179] does[0.168] n't[0.178] infringe[0.073] on[0.106] anyone[0.209] else[0.217] 's[0.194] patents[0.147] ,[0.224] "[0.289] says[0.282] Johnsee[0.494] Lee[0.587] .[0.224]
#
# Uh[0.334] Jimmy[0.408] Carter[0.518] got[0.187] uh[0.237] an[0.200] agreement[0.163] which[0.232] was[0.224] later[0.213] violated[0.175] regrettably[0.170] with[0.200] the[0.297] father[0.318] Kim[0.502] Jong[0.400] -[0.304] Il[0.371] /.[0.236]
#
# To[0.239] help[0.135] us[0.204] scrutinize[0.105] the[0.173] coverage[0.142] I[0.308] sat[0.198] down[0.229] with[0.259] a[0.256] foreign[0.187] affairs[0.163] columnist[0.250] of[0.164] the[0.246] New[0.233] York[0.242] Times[0.302] three[0.248] time[0.189] Pulitzer[0.268] winner[0.297] Tom[0.446] Friedman[0.522] and[0.269] the[0.273] author[0.253] most[0.199] recently[0.311] of[0.236] The[0.271] World[0.272] is[0.193] Flat[0.290] /.[0.213]
#
# When[0.302] foreign[0.221] firms[0.222] in[0.159] the[0.189] mainland[0.227] are[0.174] confronted[0.168] with[0.164] threats[0.167] to[0.131] their[0.125] safety[0.186] and[0.177] property[0.218] ,[0.292] "[0.297] Hong[0.376] Kong[0.436] can[0.175] count[0.159] on[0.146] the[0.202] cooperation[0.170] of[0.172] the[0.260] government[0.299] ,[0.264] US[0.320] and[0.220] Japanese[0.327] businesses[0.283] can[0.186] turn[0.177] to[0.213] their[0.190] ambassadors[0.226] ,[0.305] but[0.269] what[0.208] can[0.197] Taiwan[0.303] firms[0.180] do[0.199] ?[0.206] "[0.300] asks[0.266] Yeh[0.586] .[0.257]
#
# At[0.247] home[0.186] ,[0.212] President[0.299] Vojislav[0.289] Kostunica[0.415] says[0.209] that[0.200] he[0.335] intends[0.143] to[0.164] promote[0.105] democracy[0.183] and[0.178] free[0.130] speech[0.211] ,[0.231] but[0.245] Kostunica[0.415] just[0.255] might[0.185] have[0.174] second[0.146] thoughts[0.155] ,[0.269] once[0.196] a[0.198] theater[0.141] group[0.183] that[0.250] roasted[0.134] his[0.212] predecessor[0.249] over[0.171] the[0.142] coals[0.168] starts[0.148] turning[0.181] him[0.246] on[0.205] a[0.143] spit[0.152] .[0.214]
#
# Robertson[0.538] 's[0.194] African[0.229] interests[0.160] also[0.201] crossed[0.126] paths[0.123] with[0.175] Bout[0.409] 's[0.206] in[0.172] another[0.177] country[0.191] --[0.188] the[0.216] former[0.176] Zaire[0.292] .[0.211]
#
# ``[0.250] As[0.247] businesses[0.174] contract[0.115] or[0.130] depart[0.123] ,[0.195] the[0.208] number[0.148] of[0.087] employees[0.203] who[0.230] might[0.127] use[0.097] retail[0.143] services[0.191] shrinks[0.124] ,[0.245] ''[0.291] says[0.298] Edward[0.517] A.[0.427] Friedman[0.556] ,[0.301] senior[0.235] vice[0.226] president[0.287] of[0.193] Helmsley[0.368] Spear[0.391] Inc[0.298] .[0.275]
#
# and[0.269] he[0.376] has[0.268] Ron[0.369] 's[0.190] expressions[0.094] .[0.205]
#
# but[0.229] first[0.203] Judy[0.393] Miller[0.497] and[0.200] the[0.195] New[0.198] York[0.200] Times[0.263] finally[0.195] go[0.156] public[0.147] on[0.143] the[0.128] front[0.114] page[0.157] this[0.157] morning[0.194] with[0.176] their[0.165] nearly[0.107] six[0.148] thousand[0.123] word[0.114] account[0.169] of[0.174] the[0.197] CIA[0.223] leak[0.131] investigation[0.220] /.[0.183]
#
# American[0.333] and[0.184] Japanese[0.324] officials[0.293] offered[0.187] several[0.162] theories[0.144] for[0.190] the[0.181] difference[0.142] in[0.151] approach[0.194] betwen[0.080] Mr.[0.376] Mosbacher[0.442] and[0.311] Mrs.[0.319] Hills[0.310] .[0.200]
#
# I[0.342] was[0.236] asking[0.205] to[0.167] talk[0.189] about[0.164] facts[0.150] that[0.224] Freeh[0.412] was[0.254] saying[0.208] that[0.231] were[0.182] not[0.185] true[0.198] /.[0.196]
#
# I[0.342] was[0.236] asking[0.205] to[0.167] talk[0.189] about[0.164] facts[0.150] that[0.224] Freeh[0.412] was[0.254] saying[0.208] that[0.231] were[0.182] not[0.185] true[0.198] /.[0.196]
#
# ``[0.256] I[0.355] was[0.267] buying[0.172] at[0.180] the[0.201] close[0.187] -LRB-[0.190] Friday[0.287] -RRB-[0.186] and[0.262] I[0.342] 'll[0.196] be[0.175] buying[0.153] again[0.227] because[0.198] I[0.325] know[0.184] we[0.229] 're[0.124] getting[0.158] good[0.126] value[0.120] ,[0.240] ''[0.277] said[0.332] Frederick[0.521] A.[0.414] Moran[0.563] ,[0.302] president[0.298] of[0.214] Moran[0.469] Asset[0.274] Management[0.327] Inc.[0.283] ,[0.294] Greenwich[0.317] ,[0.197] Conn[0.311] .[0.238]
#
# For[0.266] example[0.156] ,[0.262] Sen.[0.308] Sam[0.326] Brownback[0.421] -LRB-[0.217] R[0.343] -[0.269] Kans.[0.280] -RRB-[0.218] ,[0.266] the[0.252] delirious[0.140] End[0.252] -[0.266] Timer[0.348] ,[0.268] has[0.244] lived[0.152] in[0.142] the[0.166] cult[0.082] 's[0.187] house[0.202] in[0.155] Washington[0.345] .[0.210]
#
# "[0.278] There[0.337] 's[0.188] a[0.143] lot[0.127] more[0.151] than[0.144] you[0.252] 'd[0.150] think[0.205] to[0.166] growing[0.165] wax[0.154] apples[0.211] ,[0.220] "[0.305] says[0.294] local[0.296] farmer[0.334] Chen[0.596] Sheng[0.570] -[0.262] tzung[0.210] .[0.225]
#
# Little[0.321] Beiwen[0.536] has[0.244] not[0.227] seen[0.155] them[0.199] once[0.214] in[0.155] the[0.157] past[0.138] six[0.180] years[0.231] .[0.219]
#
# Al[0.325] Gore[0.423] wo[0.258] n't[0.213] be[0.179] the[0.182] next[0.146] U.S.[0.182] President[0.291] ,[0.269] but[0.244] he[0.361] has[0.255] a[0.163] slim[0.077] chance[0.156] of[0.146] becoming[0.171] the[0.202] next[0.164] President[0.307] at[0.174] Harvard[0.347] .[0.211]
#
# And[0.293] you[0.260] see[0.208] Apache[0.190] helicopter[0.158] pilot[0.171] and[0.225] his[0.240] wife[0.289] Michelle[0.403] who[0.316] was[0.259] talking[0.191] with[0.195] us[0.263] on[0.188] the[0.148] telephone[0.173] the[0.164] Sunday[0.216] morning[0.181] when[0.243] the[0.221] video[0.120] came[0.184] in[0.205] of[0.164] the[0.178] rescue[0.106] of[0.154] the[0.204] POWs[0.217] and[0.222] ,[0.237] she[0.339] identified[0.173] her[0.257] husband[0.294] and[0.248] life[0.222] just[0.165] got[0.141] better[0.160] and[0.180] better[0.146] for[0.119] her[0.251] after[0.162] that[0.215] .[0.196]
#
# I[0.334] disagree[0.138] with[0.180] the[0.230] statement[0.175] by[0.167] Mr.[0.359] Lantos[0.405] that[0.218] one[0.233] should[0.163] not[0.173] draw[0.123] an[0.148] adverse[0.038] inference[0.073] against[0.101] former[0.193] HUD[0.201] officials[0.256] who[0.227] assert[0.102] their[0.154] Fifth[0.208] Amendment[0.161] privilege[0.175] against[0.086] self[0.117] -[0.193] incrimination[0.087] in[0.119] congressional[0.107] hearings[0.161] .[0.195]
#
# Anonymous[0.242] quoted[0.216] ,[0.284] ``[0.289] Jackson[0.466] 's[0.249] stay[0.193] at[0.160] the[0.237] Cedars[0.313] was[0.208] arranged[0.175] through[0.159] David[0.467] Kuo[0.526] ...[0.232] ''[0.309]
#
# I[0.334] am[0.199] Tony[0.428] Kahn[0.548] .[0.215]
#
# In[0.244] the[0.159] seven[0.145] Supreme[0.176] Court[0.199] terms[0.140] from[0.171] the[0.170] fall[0.148] of[0.161] 1962[0.249] through[0.148] the[0.174] spring[0.161] of[0.186] 1967[0.262] ,[0.225] the[0.181] height[0.093] of[0.145] the[0.174] Warren[0.302] Court[0.243] 's[0.171] power[0.137] ,[0.185] Justice[0.350] Brennan[0.495] cast[0.129] only[0.141] 25[0.193] dissenting[0.095] votes[0.142] in[0.139] 555[0.135] cases[0.176] decided[0.187] by[0.126] the[0.180] court[0.201] .[0.190]
#
# And[0.300] this[0.219] is[0.193] another[0.159] reason[0.131] why[0.155] I[0.320] think[0.166] for[0.128] a[0.126] relatively[0.088] cheap[0.078] price[0.175] a[0.152] face[0.174] to[0.144] face[0.198] negotiation[0.192] at[0.185] the[0.163] level[0.105] of[0.133] Chris[0.379] Hill[0.422] who[0.346] again[0.276] is[0.230] very[0.182] competent[0.176] I[0.299] believe[0.191] would[0.189] set[0.137] the[0.116] stage[0.084] for[0.160] a[0.148] final[0.145] agreement[0.164] at[0.174] the[0.191] six[0.158] party[0.150] talks[0.214] Which[0.286] is[0.220] essential[0.180] Which[0.301] is[0.216] basically[0.162] a[0.179] good[0.135] agreement[0.168] /.[0.182]
#
# And[0.299] I[0.324] do[0.169] not[0.202] believe[0.154] that[0.221] Rumsfeld[0.405] would[0.201] meet[0.159] Saddam[0.329] unless[0.129] Saddam[0.339] himself[0.278] made[0.169] signs[0.095] ...[0.172] the[0.194] important[0.083] thing[0.131] is[0.178] that[0.216] the[0.199] expression[0.115] quoted[0.215] above[0.196] tells[0.172] of[0.123] a[0.131] reality[0.141] that[0.257] can[0.144] not[0.153] be[0.168] but[0.189] accepted[0.176] ...[0.169]
#
# We[0.292] do[0.142] n't[0.173] know[0.168] who[0.259] eh[0.165] her[0.253] source[0.150] was[0.251] when[0.184] it[0.215] comes[0.134] to[0.127] revealing[0.128] the[0.158] identity[0.116] of[0.125] Valerie[0.294] Plame[0.305] /.[0.199]
#
# The[0.242] real[0.152] pioneers[0.148] are[0.147] men[0.261] like[0.170] John[0.443] Sheltons[0.421] who[0.259] explore[0.070] underground[0.074] caves[0.106] .[0.211]
#
# Today[0.282] ,[0.225] Peilice[0.508] Dekuliar[0.409] ,[0.253] the[0.245] UN[0.215] Secretary[0.276] -[0.276] General[0.283] ,[0.258] expressed[0.147] grief[0.174] at[0.145] the[0.174] multi-national[0.106] forces[0.133] air[0.108] striking[0.122] Baghdad[0.234] resulting[0.105] in[0.110] civilians[0.144] deaths[0.145] .[0.203]
#
# Life[0.296] is[0.120] a[0.122] process[0.122] that[0.214] moves[0.143] from[0.106] the[0.124] "[0.142] outward[0.073] "[0.137] to[0.129] the[0.135] "[0.121] inward[0.097] ,[0.184] "[0.246] says[0.289] Alice[0.475] Lu[0.609] ,[0.302] director[0.283] of[0.205] the[0.275] International[0.221] Family[0.222] Life[0.226] Education[0.222] Center[0.298] ,[0.295] getting[0.186] to[0.155] the[0.164] heart[0.151] of[0.151] the[0.167] matter[0.197] .[0.210]
#
# Now[0.295] ,[0.250] with[0.180] a[0.142] third[0.151] season[0.129] set[0.167] to[0.136] start[0.134] ,[0.241] will[0.200] Ozzy[0.262] 's[0.187] role[0.117] as[0.141] a[0.149] family[0.147] man[0.198] change[0.130] the[0.141] image[0.092] in[0.113] the[0.137] annuls[0.112] of[0.117] heavy[0.111] metal[0.121] mad[0.138] man[0.218] ?[0.170]
#
# Rep.[0.280] Panetta[0.413] said[0.272] that[0.237] OMB[0.300] 's[0.217] figure[0.172] would[0.162] still[0.135] be[0.141] enough[0.158] to[0.179] avoid[0.097] permanent[0.050] across[0.092] -[0.198] the[0.198] -[0.199] board[0.171] cuts[0.170] ,[0.223] but[0.236] added[0.223] :[0.196] ``[0.255] We[0.299] 're[0.153] getting[0.166] very[0.163] close[0.173] to[0.145] the[0.146] margins[0.149] here[0.268] .[0.200] ''[0.290]
#
# Ah[0.286] but[0.225] you[0.264] certainly[0.206] and[0.240] you[0.269] 're[0.164] uh[0.228] on[0.204] a[0.167] blog[0.152] so[0.178] maybe[0.149] it[0.264] 's[0.171] a[0.137] different[0.074] standard[0.107] have[0.146] speculated[0.164] about[0.156] Rove[0.342] 's[0.182] fate[0.140] as[0.181] well[0.249] /.[0.187]
#
# Most[0.249] of[0.166] those[0.212] that[0.212] took[0.163] the[0.146] view[0.134] at[0.183] that[0.182] time[0.181] ,[0.249] think[0.160] until[0.176] recently[0.247] they[0.233] were[0.160] correct[0.148] in[0.130] saving[0.144] Saddam[0.327] Hussein[0.393] .[0.193]
#
# Energy[0.236] Secretary[0.251] Bill[0.326] Richardson[0.568] says[0.208] it[0.288] is[0.146] a[0.127] case[0.159] of[0.145] demand[0.124] outpacing[0.046] supplies[0.122] .[0.201]
#
# ``[0.247] The[0.257] question[0.167] is[0.212] how[0.167] much[0.182] are[0.145] we[0.171] getting[0.180] from[0.150] each[0.163] reader[0.191] ,[0.246] ''[0.305] said[0.357] Mr.[0.440] Heinemann[0.493] .[0.204]
#
# After[0.264] the[0.184] angry[0.091] outburst[0.138] Mr.[0.373] Arafat[0.387] reaffirmed[0.187] his[0.197] commitment[0.151] to[0.093] peace[0.151] and[0.202] his[0.185] willingness[0.134] to[0.146] meet[0.152] Mr.[0.359] Barak[0.448] .[0.210]
#
# their[0.180] story[0.196] says[0.228] that[0.233] Bill[0.411] Keller[0.491] and[0.264] Arthur[0.409] Sulzberger[0.392] did[0.191] not[0.201] press[0.175] Judy[0.348] Miller[0.465] about[0.187] her[0.154] conversations[0.131] with[0.162] Libby[0.391] or[0.216] ask[0.180] to[0.176] see[0.188] her[0.226] notes[0.151] while[0.171] they[0.229] were[0.182] defending[0.207] her[0.269] /.[0.193]
#
# Uh[0.323] Mister[0.295] Ambassador[0.352] many[0.201] critics[0.197] will[0.198] say[0.205] the[0.176] six[0.155] years[0.151] George[0.385] Bush[0.440] has[0.263] been[0.210] president[0.289] North[0.298] Korea[0.378] 's[0.217] program[0.221] has[0.198] developed[0.153] rather[0.140] dramatically[0.193] That[0.294] the[0.173] policy[0.176] at[0.136] first[0.156] of[0.085] isolation[0.126] and[0.172] then[0.163] the[0.172] six[0.176] party[0.145] talk[0.186] just[0.216] has[0.218] n't[0.210] worked[0.191] /.[0.180]
#
# We[0.302] 're[0.156] normal[0.163] people[0.235] ,[0.231] and[0.238] that[0.264] 's[0.231] what[0.203] Pelswick[0.438] was[0.268] ,[0.274] he[0.344] was[0.255] just[0.217] a[0.192] normal[0.137] kid[0.183] .[0.210]
#
# -LRB-[0.271] Laura[0.446] Li[0.572] /[0.174] photos[0.147] by[0.215] Hsueh[0.523] Chi[0.489] -[0.275] kuang[0.272] /[0.104] tr.[0.130] by[0.191] Jonathan[0.441] Barnard[0.490] -RRB-[0.224]
#
# Mr.[0.413] Watkins[0.574] said[0.248] the[0.215] main[0.106] reason[0.121] for[0.145] the[0.164] production[0.162] decline[0.170] is[0.171] shrinking[0.096] output[0.165] of[0.100] light[0.125] crude[0.148] from[0.106] mature[0.060] ,[0.093] conventional[0.062] fields[0.133] in[0.120] western[0.133] Canada[0.334] .[0.198]
#
# Robert[0.478] Kolb[0.463] and[0.249] Ricardo[0.329] Rodriguez[0.425] ,[0.226] professors[0.246] of[0.144] finance[0.204] at[0.211] the[0.249] University[0.293] of[0.144] Miami[0.344] ,[0.299] found[0.136] evidence[0.146] that[0.201] the[0.200] market[0.172] is[0.163] spooked[0.122] by[0.159] Friday[0.292] the[0.151] 13th[0.147] .[0.195]
#
# "[0.294] We[0.312] do[0.184] n't[0.214] take[0.152] much[0.176] of[0.152] a[0.181] break[0.184] for[0.178] the[0.205] Chinese[0.292] New[0.240] Year[0.267] 's[0.260] holidays[0.184] ,[0.251] "[0.316] says[0.322] Andrew[0.559] Yeh[0.599] ,[0.352] chairman[0.367] of[0.270] Dongguan[0.383] 's[0.248] Powin[0.369] Electric[0.279] ,[0.274] which[0.279] makes[0.176] cable[0.150] for[0.154] the[0.182] telecoms[0.151] industry[0.248] .[0.223]
#
# Israel[0.365] 's[0.189] Foreign[0.239] Minister[0.289] ,[0.257] Shimon[0.326] Peres[0.442] ,[0.380] said[0.263] that[0.209] China[0.381] ,[0.201] by[0.126] persevering[0.109] in[0.122] going[0.145] its[0.070] own[0.115] way[0.164] ,[0.253] and[0.179] concentrating[0.119] its[0.132] efforts[0.165] on[0.093] conquering[0.083] poverty[0.174] set[0.126] an[0.123] example[0.144] for[0.124] the[0.177] people[0.222] of[0.120] every[0.104] country[0.170] of[0.121] the[0.151] Middle[0.158] East[0.244] .[0.208]
#
# At[0.240] the[0.152] lounge[0.126] ,[0.245] manager[0.251] Elizabeth[0.428] Dyer[0.506] wo[0.294] n't[0.264] admit[0.157] patrons[0.198] in[0.188] jeans[0.182] ,[0.195] T[0.281] -[0.209] shirts[0.170] or[0.136] tennis[0.146] shoes[0.174] .[0.209]
#
# With[0.241] loving[0.054] detail[0.147] she[0.330] recalls[0.193] her[0.232] Uncle[0.290] Gabe[0.390] ,[0.280] an[0.233] Orthodox[0.159] Jew[0.292] and[0.205] song[0.193] lyricist[0.197] -LRB-[0.232] who[0.307] rhymed[0.095] river[0.148] with[0.144] liver[0.148] in[0.154] a[0.159] love[0.088] song[0.196] -RRB-[0.202] ;[0.198] and[0.284] Uncle[0.284] Len[0.469] ,[0.269] a[0.206] mysterious[0.085] part[0.207] -[0.250] time[0.192] investigator[0.199] who[0.324] looked[0.199] like[0.143] Lincoln[0.361] and[0.252] carried[0.162] a[0.157] change[0.139] of[0.096] clothing[0.198] in[0.150] a[0.140] Manila[0.172] envelope[0.137] ,[0.271] like[0.170] an[0.218] ``[0.224] undercover[0.097] President[0.344] on[0.139] a[0.162] good[0.110] -[0.190] will[0.207] mission[0.145] .[0.192] ''[0.264]
#
# Well[0.319] ,[0.276] ,[0.275] Leo[0.431] 's[0.221] big[0.134] .[0.201] You[0.265] know[0.215] ,[0.257]
#
# Qichen[0.484] Qian[0.582] told[0.234] the[0.245] French[0.170] guest[0.189] that[0.258] France[0.350] is[0.166] the[0.152] first[0.136] big[0.104] western[0.116] country[0.162] to[0.155] establish[0.109] diplomatic[0.122] relations[0.193] with[0.155] China[0.379] ,[0.272] and[0.272] that[0.261] over[0.203] the[0.196] past[0.116] 30[0.215] years[0.210] since[0.218] the[0.215] establishment[0.176] of[0.136] diplomatic[0.139] relations[0.211] between[0.115] China[0.351] and[0.163] France[0.322] ,[0.263] the[0.232] development[0.190] of[0.118] bilateral[0.155] relations[0.208] has[0.195] been[0.175] satisfactory[0.129] overall[0.156] despite[0.128] some[0.151] complications[0.149] .[0.211]
#
# apparently[0.195] like[0.168] at[0.202] Lisa[0.352] Manachi[0.385] 's[0.224] wedding[0.186] like[0.153] the[0.154] whole[0.105] night[0.202] people[0.250] were[0.191] talking[0.188] about[0.194] how[0.146] bad[0.103] the[0.154] black[0.174] dresses[0.122] were[0.174] .[0.188]
#
# Topping[0.306] the[0.190] cheese[0.196] stunt[0.116] ,[0.252] on[0.141] another[0.135] typical[0.085] evening[0.164] of[0.081] fun[0.146] on[0.145] ``[0.273] Wetten[0.373] Dass[0.400] ,[0.292] ''[0.280] a[0.205] contestant[0.176] won[0.172] a[0.136] bet[0.101] with[0.178] the[0.239] show[0.209] 's[0.166] host[0.218] ,[0.267] Thomas[0.484] Gottschalk[0.507] ,[0.297] that[0.224] he[0.317] could[0.154] identify[0.103] 300[0.150] German[0.184] dialects[0.104] over[0.166] the[0.154] telephone[0.163] .[0.196]
#
# Chang[0.586] also[0.318] notes[0.217] that[0.253] when[0.216] people[0.223] come[0.158] to[0.130] forks[0.161] in[0.124] the[0.130] road[0.140] when[0.179] they[0.206] reach[0.090] middle[0.132] age[0.152] ,[0.207] they[0.217] may[0.132] look[0.151] around[0.141] in[0.096] all[0.084] directions[0.115] and[0.176] feel[0.078] at[0.133] a[0.100] loss[0.146] ,[0.211] but[0.214] they[0.240] 've[0.170] got[0.150] to[0.158] encourage[0.101] themselves[0.140] to[0.146] keep[0.139] pressing[0.127] ahead[0.137] .[0.202]
#
# After[0.296] assuming[0.202] the[0.181] presidency[0.223] ,[0.334] Chen[0.616] Shui[0.469] -[0.355] bian[0.389] recruited[0.229] a[0.234] number[0.172] of[0.159] leading[0.193] politicians[0.264] ,[0.250] industrialists[0.269] ,[0.211] academics[0.302] and[0.236] other[0.205] personages[0.203] for[0.208] a[0.220] non-partisan[0.119] advisory[0.166] group[0.239] ,[0.324] intended[0.200] to[0.180] build[0.096] cross-party[0.064] consensus[0.136] on[0.194] the[0.201] subject[0.228] of[0.165] relations[0.198] with[0.179] the[0.227] mainland[0.254] .[0.230]
#
# When[0.288] the[0.202] news[0.206] broke[0.153] of[0.157] an[0.157] attempted[0.062] coup[0.157] in[0.143] Panama[0.250] two[0.189] weeks[0.145] ago[0.229] ,[0.232] Sen.[0.289] Christopher[0.366] Dodd[0.450] called[0.185] the[0.206] State[0.233] Department[0.273] for[0.167] a[0.165] briefing[0.177] .[0.212]
#
# Along[0.251] with[0.164] the[0.147] picture[0.123] ,[0.226] the[0.252] flight[0.183] attendant[0.148] wrote[0.249] a[0.177] letter[0.168] saying[0.214] she[0.319] was[0.219] praying[0.144] for[0.165] Jack[0.390] 's[0.179] safe[0.070] return[0.191] .[0.198]
#
# Barbara[0.425] Plett[0.422] ,[0.252] BBC[0.234] News[0.260] ,[0.261] Baghdad[0.294] .[0.206]
#
# Saddam[0.375] Hussein[0.432] :[0.172] Then[0.298] you[0.239] want[0.110] a[0.161] new[0.122] lackey[0.142] to[0.149] be[0.174] added[0.213] to[0.172] this[0.158] queue[0.137] of[0.076] lackeys[0.142] .[0.204]
#
# More[0.245] of[0.177] my[0.184] interview[0.205] with[0.215] Tom[0.437] Friedman[0.478] next[0.196] /.[0.203]
#
# The[0.288] Fellowship[0.272] paid[0.132] $[0.176] 1.5[0.227] million[0.184] for[0.166] the[0.239] Cedars[0.324] ,[0.243] the[0.179] money[0.228] coming[0.176] from[0.181] Tom[0.437] Phillips[0.483] ,[0.266] the[0.253] CEO[0.292] of[0.188] Raytheon[0.318] ,[0.289] and[0.284] Ken[0.467] Olsen[0.508] ,[0.293] the[0.270] CEO[0.316] of[0.172] Digital[0.195] Equipment[0.234] Corporation[0.285] .[0.220]
#
# Zhen[0.521] Wang[0.622] ,[0.370] a[0.333] businessman[0.339] of[0.253] Chinese[0.255] descent[0.255] who[0.406] is[0.311] representing[0.249] the[0.294] Guangzhou[0.311] chapter[0.238] of[0.221] the[0.288] American[0.271] Chamber[0.219] of[0.200] Commerce[0.349] and[0.317] the[0.307] Xian[0.398] Ni[0.398] Lei[0.475] De[0.343] Group[0.332] and[0.337] is[0.306] participating[0.265] in[0.270] the[0.264] lobbying[0.204] team[0.291] ,[0.450] said[0.316] to[0.207] this[0.240] reporter[0.273] that[0.271] ,[0.274] as[0.219] a[0.205] follow[0.184] -[0.295] up[0.184] action[0.198] to[0.163] this[0.193] lobbying[0.174] effort[0.234] ,[0.307] he[0.386] prepared[0.214] to[0.195] mobilize[0.113] tens[0.191] of[0.105] thousands[0.219] of[0.126] distributors[0.233] who[0.245] belong[0.132] to[0.177] the[0.218] company[0.267] to[0.173] write[0.172] to[0.193] their[0.190] local[0.201] congressional[0.157] representatives[0.260] to[0.190] support[0.196] extending[0.151] China[0.340] 's[0.207] most[0.119] -[0.198] favored[0.179] -[0.226] nation[0.181] trading[0.150] status[0.166] .[0.218]
#
# So[0.332] Francis[0.504]
#
# But[0.331] then[0.262] later[0.267] he[0.381] called[0.236] him[0.332] Mister[0.311] Kim[0.538] Jong[0.407] -[0.313] Il[0.374] /.[0.253]
#
# Mr[0.383] Rumsfeld[0.442] ,[0.276] you[0.254] have[0.201] committed[0.123] the[0.131] greatest[0.047] crime[0.150] in[0.103] history[0.182] against[0.086] a[0.144] peaceful[0.045] Arab[0.144] state[0.205] ..[0.146] we[0.233] met[0.162] each[0.164] other[0.246] in[0.143] the[0.161] eighties[0.139] .[0.202]
#
# Italian[0.241] President[0.251] Francesco[0.283] Cossiga[0.414] promised[0.159] a[0.150] quick[0.111] investigation[0.186] into[0.148] whether[0.159] Olivetti[0.328] broke[0.126] Cocom[0.300] rules[0.177] .[0.211]
#
# David[0.494] Williams[0.560] ,[0.295] one[0.263] of[0.180] the[0.216] POWs[0.237] whose[0.142] face[0.195] we[0.215] got[0.197] to[0.144] know[0.222] in[0.163] the[0.163] coverage[0.126] that[0.216] we[0.199] saw[0.194] coming[0.173] from[0.160] Iraq[0.305] .[0.219]
#
# Introducing[0.211] pool[0.088] ,[0.180] argued[0.248] Councilwoman[0.247] Riley[0.556] Reinker[0.532] ,[0.276] would[0.171] be[0.159] ``[0.209] dangerous[0.128] .[0.201]
#
# The[0.249] U.S.[0.241] attorney[0.249] says[0.197] Padilla[0.414] is[0.207] an[0.190] enemy[0.104] combattant[0.130] and[0.220] not[0.173] entitled[0.184] to[0.145] counsel[0.210] .[0.212]
#
# Mr.[0.410] Amos[0.537] says[0.227] the[0.248] Shaw[0.429] -[0.243] Crier[0.298] team[0.206] will[0.186] probably[0.127] do[0.153] two[0.170] live[0.064] interviews[0.152] a[0.139] day[0.205] ,[0.218] with[0.175] most[0.149] of[0.161] the[0.151] program[0.184] ,[0.214] at[0.166] least[0.116] for[0.145] now[0.246] ,[0.257] appearing[0.146] similar[0.155] to[0.160] CNN[0.240] 's[0.189] other[0.173] newcasts[0.178] .[0.201]
#
# Speaker[0.270] Newt[0.362] Gingrich[0.450] the[0.235] former[0.199] speaker[0.255] Republican[0.270] weighed[0.156] in[0.195] on[0.149] this[0.187] debate[0.183] in[0.161] this[0.161] way[0.218] /.[0.195]
#
# Might[0.230] get[0.156] more[0.152] information[0.157] from[0.179] Secretary[0.251] Tom[0.362] Ridge[0.324] when[0.239] he[0.355] delivers[0.183] that[0.214] speech[0.240] over[0.163] at[0.202] the[0.208] press[0.189] club[0.196] in[0.167] the[0.176] next[0.135] hour[0.186] .[0.214]

# %%
text = ''
text += format_labeled_examples(tokens_train, tags_train)
text += format_inference_results(tokens_test_sim['nearest'])
print(text)
# Out:
# +++++++++ Input examples +++++++++
#
# Gambling , however , is not one of the vices [[Bennett]] thinks is undermining American culture .
#
# So [[John]] [[McCall]] was doing it %uh last week
#
# [[Xiulian]] [[Gu]] , minister of the Chemical Industry Ministry , pointed out in her keynote report made at the conference that although China 's chemical industry unflinchingly faced an austere situation of many profit decreasing factors and slipping benefits , it took the deepening of state - owned enterprise reforms as a breach and completed the whole year 's production and construction tasks relatively well .
#
# We begin where he began this journey , in Austin , Texas and NBC News correspondent [[Campbell]] [[Brown]] .
#
# As part of his efforts to attract more Taiwanese investors to do business in Macau , he helped introduce President Group CEO [[Kao]] [[Chin]] [[-]] [[yen]] to the territory , and in order to build better ties with the mainland Chinese , he helped the Xinhua News Agency in Macau to install satellite TV .
#
# `` You 're not going to make it in a 5 % bank account , '' says [[James]] [[Riepe]] , director of mutual funds at T. Rowe Price .
#
# [[Albert]] [[Fried]] [[Jr.]] , a 59 - year - old director and holder of a 9.5 % stake in the company , was named chairman of this maker of products for the construction equipment , material handling and railroad industries .
#
# US Defense Secretary [[William]] [[Cohen]] plans to travel next week to nine Middle Eastern Gulf states for meetings with regional leaders .
#
# Cross-strait relations , said [[Chen]] , were just one of many issues that he discussed with [[Lee]] .
#
# " Many people just discuss Floating Life from the perspective of immigration , " [[Law]] says , " but what I really intended to show was how fleeting life is , and how people go about surviving in rootless societies . "
#
# +++++++++ Tests +++++++++
#
# The[0.240] singer[0.222] was[0.303] brother[0.212] Jermaine[0.277] ,[0.421] and[0.285] the[0.179] claims[0.185] based[0.188] on[0.229] the[0.210] projected[0.153] outline[0.164] for[0.271] his[0.188] abandoned[0.101] ``[0.166] tell[0.139] -[0.574] all[0.175] ''[0.242] family[0.190] story[0.230] .[0.291]
#
# As[0.266] Greg[0.378] Lefevre[0.389] reports[0.246] ,[0.370] many[0.185] stores[0.179] have[0.245] sold[0.141] out[0.221] of[0.214] the[0.190] game[0.169] even[0.251] before[0.224] its[0.172] release[0.204] .[0.289]
#
# Dr.[0.352] Johnsee[0.404] Lee[0.620] ,[0.371] who[0.291] as[0.282] well[0.187] as[0.236] heading[0.154] up[0.219] the[0.189] Biomedical[0.177] Engineering[0.194] Center[0.255] is[0.290] also[0.248] general[0.185] director[0.217] of[0.181] Union[0.247] Chemical[0.253] Laboratories[0.252] ,[0.314] a[0.188] research[0.166] institute[0.180] under[0.217] the[0.180] ITRI[0.242] umbrella[0.139] ,[0.351] says[0.187] that[0.233] due[0.153] to[0.240] biochips[0.151] '[0.232] advantages[0.134] of[0.177] miniaturization[0.166] ,[0.306] parallelism[0.185] ,[0.277] speed[0.103] and[0.221] the[0.161] ability[0.135] to[0.207] reveal[0.123] the[0.177] "[0.210] big[0.155] picture[0.184] ,[0.311] "[0.241] they[0.218] have[0.209] a[0.177] very[0.128] wide[0.113] range[0.149] of[0.159] applications[0.146] .[0.279]
#
# Sen.[0.302] H.[0.321] Alexander[0.414] Smith[0.397] -LRB-[0.231] R[0.319] -[0.463] N.J.[0.312] -RRB-[0.252] ,[0.369] Buchman[0.324] 's[0.273] lieutenant[0.185] who[0.272] in[0.207] 1940[0.226] had[0.234] called[0.169] for[0.254] a[0.167] joint[0.092] world[0.110] dictatorship[0.148] of[0.168] the[0.166] United[0.154] States[0.210] ,[0.335] Britain[0.293] ,[0.300] and[0.235] Nazi[0.141] Germany[0.307] ,[0.400] brought[0.192] the[0.189] Fellowship[0.175] into[0.200] acceptance[0.130] in[0.224] Washington[0.392] .[0.293]
#
# NPR[0.286] 's[0.223] Rob[0.385] Gifford[0.411] reports[0.240] from[0.272] the[0.253] Chinese[0.309] capital[0.204] .[0.295]
#
# and[0.262] possibly[0.159] Karl[0.345] Rove[0.331] could[0.277] be[0.292] among[0.231] them[0.315] /.[0.196]
#
# and[0.306] when[0.210] she[0.287] gives[0.171] me[0.194] thumbs[0.151] down[0.239] Howie[0.362] I[0.327] have[0.231] to[0.214] put[0.163] it[0.215] in[0.215] a[0.161] ball[0.132] throw[0.189] it[0.246] in[0.220] the[0.180] circular[0.161] file[0.140] and[0.254] start[0.168] over[0.274] /.[0.201]
#
# Robert[0.546] White[0.429] ,[0.335] Canadian[0.206] Auto[0.196] Workers[0.196] union[0.159] president[0.224] ,[0.375] used[0.176] the[0.191] impending[0.088] Scarborough[0.222] shutdown[0.149] to[0.230] criticize[0.127] the[0.183] U.S.[0.155] -[0.617] Canada[0.262] free[0.165] trade[0.217] agreement[0.173] and[0.256] its[0.179] champion[0.148] ,[0.367] Prime[0.232] Minister[0.191] Brian[0.353] Mulroney[0.372] .[0.319]
#
# NPR[0.298] 's[0.191] Jerry[0.394] Hadden[0.370] reports[0.229] .[0.298]
#
# PCS[0.239] also[0.264] named[0.224] Rex[0.373] R.[0.329] Malson[0.478] ,[0.379] 57[0.247] ,[0.396] executive[0.177] vice[0.178] president[0.201] at[0.225] McKesson[0.284] ,[0.434] as[0.300] a[0.223] director[0.207] ,[0.447] filling[0.164] the[0.189] seat[0.140] vacated[0.148] by[0.316] Mr.[0.388] Field[0.283] .[0.318]
#
# The[0.255] truth[0.160] is[0.212] that[0.238] as[0.263] Howie[0.415] said[0.238] she[0.331] did[0.202] testify[0.177] /.[0.214]
#
# Chang[0.526] Der[0.433] -[0.701] chung[0.451] ,[0.336] an[0.209] associate[0.197] professor[0.234] in[0.240] the[0.212] Department[0.227] of[0.183] Living[0.239] Science[0.304] at[0.200] National[0.225] Open[0.176] University[0.252] who[0.274] worked[0.201] at[0.217] a[0.161] counseling[0.108] hotline[0.134] for[0.284] over[0.287] a[0.231] decade[0.214] ,[0.432] argues[0.185] that[0.282] any[0.188] step[0.162] in[0.251] the[0.160] right[0.142] direction[0.157] is[0.308] worthwhile[0.142] ,[0.367] no[0.157] matter[0.134] when[0.239] you[0.217] start[0.164] .[0.297]
#
# Well[0.251] not[0.202] only[0.193] is[0.273] that[0.262] false[0.109] and[0.214] President[0.330] Clinton[0.360] has[0.220] said[0.219] so[0.206] but[0.282] everybody[0.259] who[0.286] attended[0.228] the[0.211] meeting[0.245] not[0.196] including[0.221] Louis[0.399] Freeh[0.331] says[0.222] it[0.269] 's[0.280] false[0.127] /.[0.188]
#
# Richard[0.512] Chamberlain[0.415] dresses[0.166] as[0.267] a[0.182] ``[0.178] Mainland[0.287] haole[0.190] ,[0.397] ''[0.293] tucking[0.113] in[0.221] a[0.164] Hawaiian[0.194] shirt[0.163] and[0.266] rolling[0.130] up[0.214] its[0.137] long[0.153] sleeves[0.153] .[0.287]
#
# -LRB-[0.191] Teng[0.531] Sue[0.408] -[0.687] feng[0.352] /[0.254] photos[0.175] by[0.267] Jimmy[0.450] Lin[0.458] /[0.235] tr.[0.245] by[0.252] Christopher[0.442] MacDonald[0.436] -RRB-[0.191]
#
# Jackson[0.405] seems[0.235] to[0.200] be[0.267] of[0.225] this[0.195] type[0.170] .[0.282]
#
# The[0.249] reason[0.162] they[0.269] are[0.245] picking[0.132] that[0.190] particular[0.122] day[0.179] is[0.246] it[0.272] allows[0.161] ,[0.341] Brian[0.435] ,[0.367] enough[0.175] time[0.191] for[0.201] the[0.255] aggrieved[0.112] party[0.194] ,[0.391] the[0.228] losing[0.120] party[0.189] to[0.168] file[0.144] within[0.162] 10[0.167] days[0.199] a[0.175] contest[0.132] of[0.193] the[0.196] certification[0.111] and[0.261] that[0.249] still[0.180] allows[0.146] enough[0.137] time[0.149] for[0.211] the[0.181] contest[0.138] to[0.169] be[0.179] litigated[0.133] through[0.190] the[0.169] courts[0.163] primarily[0.200] the[0.196] circuit[0.165] court[0.182] and[0.205] back[0.159] to[0.220] the[0.234] Supreme[0.233] Court[0.212] if[0.205] necessary[0.156] and[0.287] still[0.198] meet[0.147] the[0.212] December[0.149] 12[0.186] deadline[0.115] for[0.251] the[0.185] Electoral[0.128] College[0.185] vote[0.201] here[0.279] .[0.294]
#
# Jerry[0.455] Shrieves[0.499] ,[0.381] UAW[0.194] local[0.162] president[0.243] ,[0.354] said[0.239] the[0.175] facility[0.173] was[0.247] asked[0.179] to[0.235] draw[0.124] up[0.204] plans[0.175] to[0.236] continue[0.165] working[0.189] as[0.249] a[0.177] ``[0.174] flex[0.112] plant[0.177] ,[0.426] ''[0.324] which[0.214] could[0.201] build[0.129] several[0.134] different[0.126] types[0.146] of[0.185] products[0.212] on[0.224] short[0.129] notice[0.138] to[0.278] satisfy[0.089] demand[0.199] .[0.283]
#
# Pat[0.447] Fitzgerald[0.449] /.[0.255]
#
# And[0.273] then[0.249] we[0.292] saw[0.191] Leo[0.345] and[0.217] Julie[0.326] at[0.217] Christmas[0.235] time[0.227] .[0.290]
#
# -LRB-[0.191] Teng[0.531] Sue[0.408] -[0.687] feng[0.352] /[0.254] photos[0.175] by[0.267] Jimmy[0.450] Lin[0.458] /[0.235] tr.[0.245] by[0.252] Christopher[0.442] MacDonald[0.436] -RRB-[0.191]
#
# ``[0.200] This[0.236] is[0.337] something[0.155] P&G[0.393] would[0.264] do[0.213] with[0.291] or[0.223] without[0.231] Kao[0.614] ,[0.488] ''[0.344] says[0.309] Mr.[0.456] Zurkuhlen[0.418] .[0.314]
#
# "[0.231] We[0.283] always[0.173] jokingly[0.195] refer[0.176] to[0.288] it[0.224] as[0.285] Fort[0.222] Pouchen[0.349] ,[0.434] "[0.288] says[0.314] Yeh[0.549] .[0.324]
#
# In[0.279] his[0.175] meeting[0.190] with[0.246] the[0.193] Uruguayan[0.222] guests[0.216] ,[0.404] Qichen[0.463] Qian[0.595] expressed[0.168] welcome[0.160] over[0.289] the[0.211] visit[0.196] by[0.303] vice[0.284] Foreign[0.247] Affairs[0.266] Minister[0.307] Kamyao[0.409] and[0.323] the[0.243] political[0.181] consultations[0.193] in[0.220] progress[0.209] .[0.320]
#
# That[0.250] shows[0.160] how[0.193] far[0.171] Ted[0.328] Turner[0.428] 's[0.226] Cable[0.221] News[0.207] Network[0.198] has[0.212] come[0.204] since[0.273] its[0.171] birth[0.190] nine[0.191] years[0.235] ago[0.295] ,[0.373] when[0.253] it[0.256] was[0.299] considered[0.200] the[0.169] laughingstock[0.080] of[0.222] television[0.194] news[0.197] .[0.304]
#
# Ever[0.214] the[0.182] rock[0.164] ,[0.315] Sharon[0.366] faced[0.145] cancer[0.208] head[0.231] on[0.232] .[0.295]
#
# Saddam[0.278] Hussein[0.371] -LRB-[0.141] in[0.214] language[0.181] beaming[0.155] with[0.192] pride[0.179] and[0.234] arrogance[0.187] -RRB-[0.198] I[0.301] want[0.185] you[0.231] first[0.211] of[0.168] all[0.207] ..[0.223] to[0.198] set[0.147] me[0.176] a[0.143] timetable[0.109] for[0.224] the[0.179] withdrawal[0.124] from[0.167] Iraq[0.251] that[0.203] your[0.157] government[0.217] will[0.224] commit[0.131] itself[0.155] to[0.234] it[0.304] in[0.206] front[0.137] of[0.195] the[0.179] world[0.160] ,[0.353] and[0.256] for[0.225] you[0.237] to[0.213] begin[0.175] the[0.194] withdrawal[0.136] operation[0.164] immediately[0.210] .[0.290]
#
# Rumsfeld[0.343] :[0.292] Stop[0.194] from[0.235] this[0.218] drivel[0.201] ,[0.364] I[0.309] am[0.223] offering[0.185] you[0.243] ...[0.323]
#
# However[0.205] ,[0.328] Pan[0.295] points[0.150] out[0.199] that[0.229] because[0.202] of[0.167] the[0.170] difficulties[0.110] in[0.181] substantially[0.103] reducing[0.105] the[0.163] time[0.144] needed[0.159] for[0.214] sample[0.138] preparation[0.135] ,[0.320] the[0.189] usefulness[0.110] of[0.191] such[0.158] a[0.187] fever[0.173] chip[0.226] is[0.272] still[0.213] limited[0.162] ,[0.383] so[0.216] that[0.247] it[0.266] can[0.205] not[0.167] yet[0.170] be[0.218] widely[0.145] promoted[0.212] .[0.288]
#
# "[0.257] We[0.275] do[0.233] n't[0.282] take[0.189] much[0.187] of[0.220] a[0.192] break[0.181] for[0.284] the[0.207] Chinese[0.312] New[0.209] Year[0.233] 's[0.255] holidays[0.196] ,[0.433] "[0.306] says[0.335] Andrew[0.655] Yeh[0.562] ,[0.438] chairman[0.265] of[0.302] Dongguan[0.463] 's[0.276] Powin[0.387] Electric[0.213] ,[0.452] which[0.268] makes[0.190] cable[0.170] for[0.281] the[0.202] telecoms[0.236] industry[0.230] .[0.319]
#
# Gao[0.534] Xingjian[0.538] arrived[0.223] in[0.248] Stockholm[0.272] this[0.251] week[0.245] and[0.337] when[0.279] he[0.319] leaves[0.183] the[0.205] Chinese[0.307] born[0.148] writer[0.214] will[0.289] have[0.261] something[0.179] extra[0.215] in[0.256] his[0.192] suitcase[0.149] ,[0.415] the[0.207] Nobel[0.182] Prize[0.191] for[0.250] Literature[0.279] .[0.313]
#
# I[0.343] am[0.258] Tony[0.438] Kahn[0.445] .[0.305]
#
# "[0.216] Because[0.249] this[0.179] area[0.197] is[0.273] a[0.156] patents[0.189] minefield[0.132] ,[0.344] it[0.286] 's[0.259] impossible[0.119] to[0.227] create[0.177] a[0.183] product[0.153] which[0.222] from[0.239] start[0.165] to[0.149] finish[0.195] does[0.202] n't[0.215] infringe[0.099] on[0.193] anyone[0.245] else[0.191] 's[0.190] patents[0.188] ,[0.352] "[0.311] says[0.317] Johnsee[0.476] Lee[0.722] .[0.321]
#
# Uh[0.245] Jimmy[0.474] Carter[0.469] got[0.236] uh[0.210] an[0.181] agreement[0.188] which[0.243] was[0.291] later[0.188] violated[0.164] regrettably[0.141] with[0.277] the[0.237] father[0.221] Kim[0.478] Jong[0.402] -[0.678] Il[0.328] /.[0.226]
#
# To[0.245] help[0.182] us[0.219] scrutinize[0.094] the[0.187] coverage[0.164] I[0.274] sat[0.208] down[0.269] with[0.239] a[0.207] foreign[0.177] affairs[0.188] columnist[0.200] of[0.186] the[0.233] New[0.248] York[0.205] Times[0.296] three[0.243] time[0.199] Pulitzer[0.268] winner[0.223] Tom[0.456] Friedman[0.453] and[0.337] the[0.237] author[0.204] most[0.236] recently[0.285] of[0.282] The[0.246] World[0.220] is[0.311] Flat[0.255] /.[0.205]
#
# When[0.261] foreign[0.222] firms[0.206] in[0.307] the[0.219] mainland[0.273] are[0.328] confronted[0.137] with[0.257] threats[0.153] to[0.244] their[0.174] safety[0.164] and[0.321] property[0.252] ,[0.409] "[0.272] Hong[0.363] Kong[0.352] can[0.235] count[0.134] on[0.245] the[0.228] cooperation[0.179] of[0.253] the[0.236] government[0.259] ,[0.401] US[0.226] and[0.311] Japanese[0.268] businesses[0.226] can[0.281] turn[0.214] to[0.352] their[0.220] ambassadors[0.201] ,[0.462] but[0.351] what[0.194] can[0.239] Taiwan[0.301] firms[0.189] do[0.183] ?[0.273] "[0.271] asks[0.247] Yeh[0.589] .[0.342]
#
# At[0.234] home[0.180] ,[0.327] President[0.268] Vojislav[0.279] Kostunica[0.404] says[0.212] that[0.261] he[0.330] intends[0.159] to[0.259] promote[0.176] democracy[0.174] and[0.264] free[0.142] speech[0.183] ,[0.411] but[0.291] Kostunica[0.381] just[0.227] might[0.208] have[0.240] second[0.163] thoughts[0.164] ,[0.388] once[0.246] a[0.193] theater[0.154] group[0.231] that[0.278] roasted[0.222] his[0.197] predecessor[0.188] over[0.235] the[0.173] coals[0.176] starts[0.167] turning[0.176] him[0.274] on[0.224] a[0.176] spit[0.176] .[0.296]
#
# Robertson[0.447] 's[0.242] African[0.174] interests[0.158] also[0.201] crossed[0.128] paths[0.137] with[0.257] Bout[0.350] 's[0.256] in[0.270] another[0.190] country[0.217] --[0.528] the[0.232] former[0.187] Zaire[0.286] .[0.326]
#
# ``[0.193] As[0.278] businesses[0.153] contract[0.126] or[0.179] depart[0.094] ,[0.331] the[0.191] number[0.133] of[0.172] employees[0.205] who[0.232] might[0.208] use[0.160] retail[0.172] services[0.166] shrinks[0.128] ,[0.376] ''[0.308] says[0.291] Edward[0.635] A.[0.424] Friedman[0.631] ,[0.333] senior[0.209] vice[0.186] president[0.234] of[0.195] Helmsley[0.303] Spear[0.315] Inc[0.318] .[0.296]
#
# and[0.317] he[0.324] has[0.275] Ron[0.330] 's[0.261] expressions[0.139] .[0.296]
#
# but[0.289] first[0.178] Judy[0.400] Miller[0.439] and[0.236] the[0.190] New[0.184] York[0.180] Times[0.275] finally[0.210] go[0.206] public[0.166] on[0.200] the[0.186] front[0.135] page[0.216] this[0.184] morning[0.242] with[0.267] their[0.209] nearly[0.149] six[0.170] thousand[0.180] word[0.153] account[0.167] of[0.192] the[0.214] CIA[0.230] leak[0.187] investigation[0.222] /.[0.200]
#
# American[0.266] and[0.219] Japanese[0.326] officials[0.308] offered[0.190] several[0.177] theories[0.132] for[0.250] the[0.182] difference[0.150] in[0.228] approach[0.178] betwen[0.127] Mr.[0.322] Mosbacher[0.383] and[0.270] Mrs.[0.306] Hills[0.264] .[0.299]
#
# I[0.334] was[0.276] asking[0.161] to[0.251] talk[0.200] about[0.230] facts[0.148] that[0.223] Freeh[0.379] was[0.294] saying[0.215] that[0.251] were[0.249] not[0.185] true[0.255] /.[0.204]
#
# I[0.334] was[0.276] asking[0.161] to[0.251] talk[0.200] about[0.230] facts[0.148] that[0.223] Freeh[0.379] was[0.294] saying[0.215] that[0.251] were[0.249] not[0.185] true[0.255] /.[0.204]
#
# ``[0.187] I[0.308] was[0.295] buying[0.194] at[0.228] the[0.190] close[0.161] -LRB-[0.162] Friday[0.239] -RRB-[0.166] and[0.298] I[0.312] 'll[0.216] be[0.249] buying[0.192] again[0.211] because[0.273] I[0.306] know[0.210] we[0.258] 're[0.236] getting[0.217] good[0.134] value[0.208] ,[0.414] ''[0.320] said[0.318] Frederick[0.657] A.[0.448] Moran[0.636] ,[0.356] president[0.242] of[0.208] Moran[0.378] Asset[0.226] Management[0.261] Inc.[0.395] ,[0.430] Greenwich[0.273] ,[0.230] Conn[0.272] .[0.266]
#
# For[0.249] example[0.139] ,[0.358] Sen.[0.313] Sam[0.344] Brownback[0.335] -LRB-[0.186] R[0.303] -[0.621] Kans.[0.233] -RRB-[0.173] ,[0.388] the[0.232] delirious[0.126] End[0.207] -[0.605] Timer[0.250] ,[0.398] has[0.262] lived[0.161] in[0.204] the[0.211] cult[0.096] 's[0.197] house[0.218] in[0.198] Washington[0.384] .[0.298]
#
# "[0.236] There[0.286] 's[0.260] a[0.232] lot[0.158] more[0.244] than[0.290] you[0.229] 'd[0.169] think[0.207] to[0.273] growing[0.203] wax[0.172] apples[0.232] ,[0.382] "[0.275] says[0.280] local[0.250] farmer[0.287] Chen[0.686] Sheng[0.545] -[0.724] tzung[0.270] .[0.310]
#
# Little[0.264] Beiwen[0.477] has[0.268] not[0.192] seen[0.159] them[0.264] once[0.230] in[0.240] the[0.194] past[0.182] six[0.213] years[0.232] .[0.294]
#
# Al[0.340] Gore[0.399] wo[0.234] n't[0.215] be[0.235] the[0.205] next[0.159] U.S.[0.155] President[0.277] ,[0.403] but[0.319] he[0.335] has[0.231] a[0.188] slim[0.096] chance[0.168] of[0.210] becoming[0.231] the[0.189] next[0.170] President[0.244] at[0.205] Harvard[0.296] .[0.300]
#
# And[0.270] you[0.252] see[0.196] Apache[0.163] helicopter[0.174] pilot[0.169] and[0.213] his[0.230] wife[0.274] Michelle[0.331] who[0.279] was[0.257] talking[0.213] with[0.231] us[0.310] on[0.192] the[0.180] telephone[0.172] the[0.172] Sunday[0.207] morning[0.213] when[0.222] the[0.195] video[0.136] came[0.208] in[0.214] of[0.183] the[0.227] rescue[0.183] of[0.210] the[0.210] POWs[0.176] and[0.240] ,[0.328] she[0.295] identified[0.143] her[0.284] husband[0.230] and[0.287] life[0.215] just[0.191] got[0.162] better[0.164] and[0.228] better[0.156] for[0.232] her[0.314] after[0.252] that[0.252] .[0.293]
#
# I[0.302] disagree[0.141] with[0.200] the[0.208] statement[0.149] by[0.241] Mr.[0.377] Lantos[0.341] that[0.234] one[0.209] should[0.206] not[0.143] draw[0.120] an[0.161] adverse[0.115] inference[0.118] against[0.191] former[0.166] HUD[0.176] officials[0.263] who[0.231] assert[0.088] their[0.159] Fifth[0.179] Amendment[0.242] privilege[0.159] against[0.183] self[0.126] -[0.578] incrimination[0.118] in[0.209] congressional[0.123] hearings[0.148] .[0.302]
#
# Anonymous[0.228] quoted[0.169] ,[0.417] ``[0.220] Jackson[0.358] 's[0.257] stay[0.192] at[0.175] the[0.221] Cedars[0.255] was[0.287] arranged[0.169] through[0.261] David[0.447] Kuo[0.457] ...[0.421] ''[0.342]
#
# I[0.343] am[0.258] Tony[0.438] Kahn[0.445] .[0.305]
#
# In[0.239] the[0.189] seven[0.156] Supreme[0.231] Court[0.242] terms[0.149] from[0.177] the[0.174] fall[0.167] of[0.168] 1962[0.177] through[0.198] the[0.163] spring[0.143] of[0.169] 1967[0.191] ,[0.303] the[0.192] height[0.126] of[0.161] the[0.181] Warren[0.282] Court[0.209] 's[0.187] power[0.131] ,[0.301] Justice[0.387] Brennan[0.392] cast[0.129] only[0.144] 25[0.162] dissenting[0.099] votes[0.157] in[0.193] 555[0.128] cases[0.156] decided[0.161] by[0.221] the[0.217] court[0.196] .[0.283]
#
# And[0.278] this[0.208] is[0.322] another[0.168] reason[0.163] why[0.175] I[0.307] think[0.188] for[0.252] a[0.187] relatively[0.145] cheap[0.136] price[0.207] a[0.177] face[0.177] to[0.191] face[0.224] negotiation[0.192] at[0.189] the[0.204] level[0.139] of[0.208] Chris[0.404] Hill[0.326] who[0.313] again[0.294] is[0.320] very[0.223] competent[0.182] I[0.367] believe[0.207] would[0.257] set[0.163] the[0.154] stage[0.119] for[0.231] a[0.171] final[0.168] agreement[0.201] at[0.212] the[0.208] six[0.155] party[0.143] talks[0.217] Which[0.261] is[0.309] essential[0.163] Which[0.276] is[0.322] basically[0.177] a[0.209] good[0.164] agreement[0.187] /.[0.195]
#
# And[0.275] I[0.305] do[0.166] not[0.178] believe[0.180] that[0.246] Rumsfeld[0.356] would[0.254] meet[0.163] Saddam[0.296] unless[0.175] Saddam[0.298] himself[0.260] made[0.206] signs[0.143] ...[0.324] the[0.210] important[0.119] thing[0.149] is[0.241] that[0.248] the[0.192] expression[0.135] quoted[0.168] above[0.185] tells[0.166] of[0.193] a[0.184] reality[0.175] that[0.286] can[0.180] not[0.159] be[0.196] but[0.277] accepted[0.190] ...[0.320]
#
# We[0.290] do[0.173] n't[0.217] know[0.195] who[0.265] eh[0.146] her[0.224] source[0.147] was[0.260] when[0.234] it[0.198] comes[0.181] to[0.256] revealing[0.145] the[0.182] identity[0.109] of[0.204] Valerie[0.327] Plame[0.250] /.[0.206]
#
# The[0.239] real[0.166] pioneers[0.145] are[0.262] men[0.247] like[0.218] John[0.746] Sheltons[0.371] who[0.242] explore[0.113] underground[0.100] caves[0.133] .[0.297]
#
# Today[0.220] ,[0.328] Peilice[0.405] Dekuliar[0.359] ,[0.322] the[0.227] UN[0.207] Secretary[0.225] -[0.576] General[0.220] ,[0.371] expressed[0.159] grief[0.169] at[0.190] the[0.185] multi-national[0.124] forces[0.163] air[0.167] striking[0.167] Baghdad[0.248] resulting[0.145] in[0.213] civilians[0.168] deaths[0.160] .[0.290]
#
# Life[0.305] is[0.240] a[0.150] process[0.145] that[0.254] moves[0.196] from[0.275] the[0.193] "[0.260] outward[0.132] "[0.258] to[0.291] the[0.196] "[0.235] inward[0.112] ,[0.364] "[0.293] says[0.316] Alice[0.524] Lu[0.567] ,[0.358] director[0.234] of[0.195] the[0.278] International[0.226] Family[0.199] Life[0.214] Education[0.215] Center[0.296] ,[0.479] getting[0.255] to[0.261] the[0.222] heart[0.129] of[0.231] the[0.186] matter[0.184] .[0.298]
#
# Now[0.247] ,[0.310] with[0.219] a[0.192] third[0.156] season[0.171] set[0.173] to[0.172] start[0.183] ,[0.307] will[0.227] Ozzy[0.202] 's[0.211] role[0.171] as[0.257] a[0.198] family[0.166] man[0.228] change[0.153] the[0.199] image[0.125] in[0.237] the[0.215] annuls[0.133] of[0.201] heavy[0.127] metal[0.130] mad[0.162] man[0.231] ?[0.280]
#
# Rep.[0.270] Panetta[0.383] said[0.214] that[0.238] OMB[0.249] 's[0.246] figure[0.175] would[0.239] still[0.164] be[0.202] enough[0.165] to[0.236] avoid[0.157] permanent[0.102] across[0.178] -[0.552] the[0.208] -[0.537] board[0.177] cuts[0.175] ,[0.407] but[0.302] added[0.179] :[0.301] ``[0.205] We[0.286] 're[0.242] getting[0.207] very[0.149] close[0.187] to[0.269] the[0.190] margins[0.196] here[0.268] .[0.294] ''[0.311]
#
# Ah[0.229] but[0.294] you[0.237] certainly[0.178] and[0.281] you[0.285] 're[0.245] uh[0.211] on[0.244] a[0.196] blog[0.156] so[0.218] maybe[0.160] it[0.280] 's[0.261] a[0.163] different[0.127] standard[0.156] have[0.215] speculated[0.164] about[0.241] Rove[0.346] 's[0.234] fate[0.156] as[0.326] well[0.244] /.[0.193]
#
# Most[0.231] of[0.193] those[0.240] that[0.231] took[0.162] the[0.164] view[0.141] at[0.206] that[0.192] time[0.179] ,[0.363] think[0.164] until[0.222] recently[0.226] they[0.251] were[0.254] correct[0.139] in[0.231] saving[0.152] Saddam[0.296] Hussein[0.316] .[0.301]
#
# Energy[0.217] Secretary[0.291] Bill[0.516] Richardson[0.530] says[0.183] it[0.259] is[0.271] a[0.165] case[0.142] of[0.215] demand[0.200] outpacing[0.101] supplies[0.137] .[0.289]
#
# ``[0.203] The[0.242] question[0.153] is[0.252] how[0.200] much[0.158] are[0.242] we[0.231] getting[0.204] from[0.264] each[0.173] reader[0.151] ,[0.384] ''[0.279] said[0.311] Mr.[0.489] Heinemann[0.484] .[0.312]
#
# After[0.251] the[0.169] angry[0.085] outburst[0.115] Mr.[0.326] Arafat[0.382] reaffirmed[0.221] his[0.183] commitment[0.143] to[0.264] peace[0.144] and[0.255] his[0.190] willingness[0.146] to[0.209] meet[0.157] Mr.[0.334] Barak[0.452] .[0.304]
#
# their[0.193] story[0.217] says[0.213] that[0.253] Bill[0.412] Keller[0.430] and[0.254] Arthur[0.488] Sulzberger[0.335] did[0.180] not[0.168] press[0.175] Judy[0.349] Miller[0.412] about[0.241] her[0.182] conversations[0.170] with[0.248] Libby[0.343] or[0.240] ask[0.145] to[0.244] see[0.230] her[0.260] notes[0.171] while[0.246] they[0.232] were[0.226] defending[0.191] her[0.301] /.[0.210]
#
# Uh[0.264] Mister[0.276] Ambassador[0.271] many[0.188] critics[0.192] will[0.261] say[0.238] the[0.202] six[0.177] years[0.197] George[0.436] Bush[0.362] has[0.273] been[0.253] president[0.243] North[0.291] Korea[0.286] 's[0.243] program[0.184] has[0.271] developed[0.175] rather[0.153] dramatically[0.223] That[0.247] the[0.197] policy[0.210] at[0.183] first[0.176] of[0.176] isolation[0.138] and[0.247] then[0.176] the[0.193] six[0.161] party[0.142] talk[0.212] just[0.217] has[0.261] n't[0.228] worked[0.188] /.[0.186]
#
# We[0.305] 're[0.221] normal[0.197] people[0.284] ,[0.369] and[0.281] that[0.267] 's[0.273] what[0.222] Pelswick[0.469] was[0.250] ,[0.365] he[0.344] was[0.268] just[0.213] a[0.192] normal[0.143] kid[0.200] .[0.283]
#
# -LRB-[0.190] Laura[0.416] Li[0.558] /[0.235] photos[0.144] by[0.271] Hsueh[0.525] Chi[0.460] -[0.679] kuang[0.337] /[0.210] tr.[0.237] by[0.248] Jonathan[0.411] Barnard[0.482] -RRB-[0.201]
#
# Mr.[0.369] Watkins[0.445] said[0.242] the[0.197] main[0.109] reason[0.143] for[0.187] the[0.183] production[0.140] decline[0.171] is[0.261] shrinking[0.128] output[0.180] of[0.203] light[0.136] crude[0.174] from[0.219] mature[0.108] ,[0.275] conventional[0.099] fields[0.127] in[0.201] western[0.150] Canada[0.281] .[0.300]
#
# Robert[0.506] Kolb[0.414] and[0.292] Ricardo[0.352] Rodriguez[0.422] ,[0.331] professors[0.217] of[0.155] finance[0.216] at[0.208] the[0.263] University[0.245] of[0.154] Miami[0.289] ,[0.370] found[0.160] evidence[0.151] that[0.259] the[0.192] market[0.242] is[0.265] spooked[0.134] by[0.285] Friday[0.253] the[0.163] 13th[0.148] .[0.292]
#
# "[0.257] We[0.275] do[0.233] n't[0.282] take[0.189] much[0.187] of[0.220] a[0.192] break[0.181] for[0.284] the[0.207] Chinese[0.312] New[0.209] Year[0.233] 's[0.255] holidays[0.196] ,[0.433] "[0.306] says[0.335] Andrew[0.655] Yeh[0.562] ,[0.438] chairman[0.265] of[0.302] Dongguan[0.463] 's[0.276] Powin[0.387] Electric[0.213] ,[0.452] which[0.268] makes[0.190] cable[0.170] for[0.281] the[0.202] telecoms[0.236] industry[0.230] .[0.319]
#
# Israel[0.376] 's[0.219] Foreign[0.204] Minister[0.285] ,[0.304] Shimon[0.339] Peres[0.456] ,[0.402] said[0.230] that[0.284] China[0.365] ,[0.412] by[0.240] persevering[0.116] in[0.223] going[0.218] its[0.190] own[0.137] way[0.185] ,[0.368] and[0.324] concentrating[0.125] its[0.147] efforts[0.176] on[0.229] conquering[0.109] poverty[0.139] set[0.166] an[0.134] example[0.142] for[0.285] the[0.197] people[0.216] of[0.213] every[0.149] country[0.190] of[0.198] the[0.196] Middle[0.135] East[0.241] .[0.297]
#
# At[0.246] the[0.153] lounge[0.120] ,[0.349] manager[0.246] Elizabeth[0.443] Dyer[0.419] wo[0.233] n't[0.243] admit[0.144] patrons[0.193] in[0.221] jeans[0.169] ,[0.295] T[0.218] -[0.622] shirts[0.161] or[0.201] tennis[0.189] shoes[0.193] .[0.302]
#
# With[0.230] loving[0.085] detail[0.147] she[0.320] recalls[0.167] her[0.247] Uncle[0.266] Gabe[0.306] ,[0.402] an[0.198] Orthodox[0.134] Jew[0.225] and[0.264] song[0.185] lyricist[0.203] -LRB-[0.166] who[0.294] rhymed[0.115] river[0.154] with[0.212] liver[0.153] in[0.226] a[0.169] love[0.100] song[0.203] -RRB-[0.175] ;[0.383] and[0.292] Uncle[0.302] Len[0.351] ,[0.472] a[0.225] mysterious[0.091] part[0.227] -[0.647] time[0.215] investigator[0.170] who[0.285] looked[0.189] like[0.255] Lincoln[0.297] and[0.320] carried[0.191] a[0.196] change[0.153] of[0.206] clothing[0.186] in[0.262] a[0.163] Manila[0.229] envelope[0.182] ,[0.447] like[0.242] an[0.197] ``[0.200] undercover[0.132] President[0.279] on[0.234] a[0.167] good[0.153] -[0.590] will[0.296] mission[0.172] .[0.306] ''[0.300]
#
# Well[0.247] ,[0.342] ,[0.350] Leo[0.442] 's[0.277] big[0.165] .[0.290] You[0.262] know[0.216] ,[0.396]
#
# Qichen[0.535] Qian[0.640] told[0.212] the[0.239] French[0.143] guest[0.143] that[0.259] France[0.327] is[0.307] the[0.199] first[0.171] big[0.162] western[0.147] country[0.220] to[0.255] establish[0.180] diplomatic[0.121] relations[0.192] with[0.284] China[0.427] ,[0.481] and[0.333] that[0.265] over[0.270] the[0.195] past[0.183] 30[0.172] years[0.195] since[0.256] the[0.207] establishment[0.167] of[0.215] diplomatic[0.143] relations[0.204] between[0.224] China[0.388] and[0.246] France[0.280] ,[0.370] the[0.241] development[0.165] of[0.211] bilateral[0.172] relations[0.198] has[0.234] been[0.235] satisfactory[0.130] overall[0.182] despite[0.194] some[0.169] complications[0.175] .[0.300]
#
# apparently[0.194] like[0.185] at[0.194] Lisa[0.313] Manachi[0.343] 's[0.228] wedding[0.211] like[0.180] the[0.184] whole[0.117] night[0.219] people[0.243] were[0.226] talking[0.214] about[0.231] how[0.183] bad[0.107] the[0.157] black[0.158] dresses[0.132] were[0.209] .[0.286]
#
# Topping[0.241] the[0.197] cheese[0.270] stunt[0.113] ,[0.349] on[0.200] another[0.146] typical[0.114] evening[0.155] of[0.185] fun[0.127] on[0.196] ``[0.213] Wetten[0.370] Dass[0.391] ,[0.401] ''[0.311] a[0.189] contestant[0.173] won[0.197] a[0.183] bet[0.193] with[0.265] the[0.254] show[0.183] 's[0.212] host[0.161] ,[0.368] Thomas[0.553] Gottschalk[0.512] ,[0.449] that[0.264] he[0.295] could[0.242] identify[0.183] 300[0.173] German[0.192] dialects[0.138] over[0.276] the[0.179] telephone[0.159] .[0.291]
#
# Chang[0.513] also[0.287] notes[0.167] that[0.264] when[0.218] people[0.209] come[0.210] to[0.235] forks[0.168] in[0.191] the[0.172] road[0.134] when[0.199] they[0.213] reach[0.141] middle[0.116] age[0.147] ,[0.310] they[0.249] may[0.173] look[0.193] around[0.187] in[0.222] all[0.129] directions[0.174] and[0.233] feel[0.137] at[0.186] a[0.179] loss[0.182] ,[0.357] but[0.289] they[0.244] 've[0.198] got[0.207] to[0.228] encourage[0.156] themselves[0.173] to[0.211] keep[0.182] pressing[0.154] ahead[0.187] .[0.293]
#
# After[0.293] assuming[0.189] the[0.198] presidency[0.182] ,[0.439] Chen[0.676] Shui[0.531] -[0.800] bian[0.358] recruited[0.227] a[0.245] number[0.219] of[0.256] leading[0.209] politicians[0.228] ,[0.407] industrialists[0.251] ,[0.342] academics[0.234] and[0.316] other[0.227] personages[0.217] for[0.344] a[0.218] non-partisan[0.140] advisory[0.185] group[0.287] ,[0.504] intended[0.227] to[0.293] build[0.199] cross-party[0.098] consensus[0.165] on[0.323] the[0.226] subject[0.178] of[0.279] relations[0.194] with[0.338] the[0.262] mainland[0.273] .[0.337]
#
# When[0.276] the[0.203] news[0.174] broke[0.176] of[0.180] an[0.161] attempted[0.091] coup[0.152] in[0.196] Panama[0.214] two[0.187] weeks[0.163] ago[0.212] ,[0.360] Sen.[0.308] Christopher[0.426] Dodd[0.401] called[0.184] the[0.225] State[0.186] Department[0.214] for[0.228] a[0.164] briefing[0.188] .[0.304]
#
# Along[0.233] with[0.246] the[0.180] picture[0.153] ,[0.350] the[0.215] flight[0.166] attendant[0.138] wrote[0.214] a[0.181] letter[0.136] saying[0.179] she[0.300] was[0.259] praying[0.132] for[0.222] Jack[0.381] 's[0.207] safe[0.099] return[0.206] .[0.292]
#
# Barbara[0.419] Plett[0.459] ,[0.332] BBC[0.280] News[0.270] ,[0.293] Baghdad[0.320] .[0.272]
#
# Saddam[0.294] Hussein[0.373] :[0.319] Then[0.271] you[0.265] want[0.195] a[0.183] new[0.172] lackey[0.177] to[0.254] be[0.297] added[0.250] to[0.307] this[0.193] queue[0.166] of[0.171] lackeys[0.204] .[0.307]
#
# More[0.197] of[0.207] my[0.179] interview[0.189] with[0.260] Tom[0.445] Friedman[0.439] next[0.218] /.[0.220]
#
# The[0.244] Fellowship[0.277] paid[0.182] $[0.217] 1.5[0.221] million[0.227] for[0.300] the[0.232] Cedars[0.269] ,[0.437] the[0.204] money[0.273] coming[0.238] from[0.262] Tom[0.479] Phillips[0.416] ,[0.388] the[0.241] CEO[0.231] of[0.210] Raytheon[0.267] ,[0.421] and[0.298] Ken[0.462] Olsen[0.488] ,[0.417] the[0.228] CEO[0.237] of[0.219] Digital[0.188] Equipment[0.165] Corporation[0.217] .[0.332]
#
# Zhen[0.564] Wang[0.614] ,[0.473] a[0.264] businessman[0.269] of[0.283] Chinese[0.273] descent[0.266] who[0.306] is[0.388] representing[0.235] the[0.258] Guangzhou[0.413] chapter[0.170] of[0.247] the[0.241] American[0.213] Chamber[0.176] of[0.209] Commerce[0.277] and[0.402] the[0.314] Xian[0.509] Ni[0.502] Lei[0.488] De[0.346] Group[0.266] and[0.437] is[0.408] participating[0.222] in[0.307] the[0.224] lobbying[0.158] team[0.242] ,[0.427] said[0.285] to[0.284] this[0.228] reporter[0.236] that[0.305] ,[0.406] as[0.341] a[0.265] follow[0.203] -[0.722] up[0.220] action[0.220] to[0.318] this[0.211] lobbying[0.207] effort[0.238] ,[0.454] he[0.317] prepared[0.212] to[0.283] mobilize[0.159] tens[0.178] of[0.194] thousands[0.205] of[0.223] distributors[0.232] who[0.300] belong[0.186] to[0.352] the[0.257] company[0.281] to[0.315] write[0.190] to[0.317] their[0.225] local[0.211] congressional[0.160] representatives[0.221] to[0.294] support[0.248] extending[0.186] China[0.334] 's[0.256] most[0.201] -[0.551] favored[0.214] -[0.569] nation[0.197] trading[0.215] status[0.146] .[0.312]
#
# So[0.297] Francis[0.456]
#
# But[0.321] then[0.246] later[0.221] he[0.337] called[0.207] him[0.273] Mister[0.289] Kim[0.464] Jong[0.415] -[0.705] Il[0.342] /.[0.222]
#
# Mr[0.345] Rumsfeld[0.369] ,[0.461] you[0.242] have[0.260] committed[0.152] the[0.187] greatest[0.077] crime[0.175] in[0.237] history[0.186] against[0.206] a[0.180] peaceful[0.096] Arab[0.135] state[0.186] ..[0.254] we[0.247] met[0.160] each[0.192] other[0.204] in[0.235] the[0.187] eighties[0.173] .[0.305]
#
# Italian[0.276] President[0.210] Francesco[0.278] Cossiga[0.420] promised[0.155] a[0.169] quick[0.129] investigation[0.166] into[0.193] whether[0.167] Olivetti[0.297] broke[0.158] Cocom[0.276] rules[0.251] .[0.281]
#
# David[0.516] Williams[0.452] ,[0.408] one[0.223] of[0.219] the[0.199] POWs[0.193] whose[0.186] face[0.165] we[0.316] got[0.188] to[0.233] know[0.201] in[0.231] the[0.225] coverage[0.166] that[0.257] we[0.332] saw[0.209] coming[0.232] from[0.232] Iraq[0.320] .[0.294]
#
# Introducing[0.176] pool[0.140] ,[0.339] argued[0.216] Councilwoman[0.233] Riley[0.458] Reinker[0.410] ,[0.445] would[0.286] be[0.265] ``[0.188] dangerous[0.137] .[0.285]
#
# The[0.232] U.S.[0.217] attorney[0.220] says[0.165] Padilla[0.394] is[0.290] an[0.182] enemy[0.118] combattant[0.125] and[0.286] not[0.244] entitled[0.150] to[0.239] counsel[0.210] .[0.283]
#
# Mr.[0.360] Amos[0.426] says[0.208] the[0.232] Shaw[0.336] -[0.638] Crier[0.239] team[0.201] will[0.252] probably[0.147] do[0.191] two[0.185] live[0.135] interviews[0.170] a[0.244] day[0.217] ,[0.411] with[0.263] most[0.202] of[0.223] the[0.198] program[0.192] ,[0.358] at[0.193] least[0.165] for[0.248] now[0.254] ,[0.403] appearing[0.180] similar[0.178] to[0.275] CNN[0.344] 's[0.238] other[0.209] newcasts[0.246] .[0.305]
#
# Speaker[0.202] Newt[0.297] Gingrich[0.409] the[0.233] former[0.184] speaker[0.202] Republican[0.241] weighed[0.141] in[0.219] on[0.246] this[0.232] debate[0.211] in[0.251] this[0.220] way[0.236] /.[0.211]
#
# Might[0.212] get[0.197] more[0.161] information[0.171] from[0.229] Secretary[0.292] Tom[0.411] Ridge[0.293] when[0.272] he[0.324] delivers[0.162] that[0.226] speech[0.232] over[0.203] at[0.189] the[0.240] press[0.177] club[0.212] in[0.227] the[0.215] next[0.157] hour[0.210] .[0.295]

# %% [markdown]
# ### Visualize similarities of tokens to NE

# %%
from IPython.core.display import display, HTML

# %%
def get_color(red=0, green=255, blue=0):
    return {'r': red, 'g': green, 'b': blue}

def get_rgba_str(color, alpha=1):
    return 'rgba({},{},{},{})'.format(color['r'], color['g'], color['b'], alpha)

def get_token_span_str(token, color, cf=1):
    return '<span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: {};">{}</span>'.format(get_rgba_str(color, alpha=cf), token)

def wrap_with_style(html):
    return '<div style="line-height: 1.5em;">{:s}</div>'.format(html)

# %%
def calc_sim_min_max(sim_list):
    sim_flat = flatten_sim(sim_list)
    sim_min = np.min(sim_flat['cosine'])
    sim_max = np.max(sim_flat['cosine'])
    return (sim_min, sim_max)

# %%
def sim_transform_lin(sim, sim_min, sim_max):
    # similarity transformation for better visualization
    return (sim - sim_min)/(sim_max - sim_min)
def sim_transform(sim, sim_min, sim_max, T=0.5):
    # similarity transformation with temperature for better visualization
    return (np.exp(sim/T) - np.exp(sim_min/T))/(np.exp(sim_max/T) - np.exp(sim_min/T))

# %%
def get_colored_results_html(tokens_sim: list, sim_min_max:tuple, color, T=0.5, caption=None):
    if sim_min_max != None:
        sim_min, sim_max = sim_min_max
    if not caption:
        caption = 'Visualization of tokens to NE similarities on test set'
    s = '<h3 style="margin-bottom:0.3em;">{}</h3>'.format(caption)
    for seq in tokens_sim:
        ch = 0
        for token, sim in seq:
            if sim_min_max != None:
                sim = sim_transform(sim, sim_min, sim_max, T)
            s += get_token_span_str(token, color, cf=sim)
            ch += len(token)
            if ch > 100:
                s += '<br/>'
                ch = 0
#             s += ' '
        s += '<br/><br/>'
    return wrap_with_style(s)

# %%
tags_list_bin_train = tags2binary(tags_train, symb=False)
tokens_train_sim = zip_tokens_sim(tokens_train, tags_list_bin_train)
display(HTML(get_colored_results_html(tokens_train_sim, (0,1), color=get_color(244,50,244), caption='Support examples')))
# Out:
# <div style="line-height: 1.5em;"><h3 style="margin-bottom:0.3em;">Support examples</h3><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(244,50,244,0.0);">Gambling</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(244,50,244,0.0);">,</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(244,50,244,0.0);">however</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(244,50,244,0.0);">,</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(244,50,244,0.0);">is</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(244,50,244,0.0);">not</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(244,50,244,0.0);">one</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(244,50,244,0.0);">of</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(244,50,244,0.0);">the</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(244,50,244,0.0);">vices</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(244,50,244,1.0);">Bennett</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(244,50,244,0.0);">thinks</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(244,50,244,0.0);">is</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(244,50,244,0.0);">undermining</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(244,50,244,0.0);">American</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(244,50,244,0.0);">culture</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(244,50,244,0.0);">.</span><br/><br/><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(244,50,244,0.0);">So</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(244,50,244,1.0);">John</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(244,50,244,1.0);">McCall</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(244,50,244,0.0);">was</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(244,50,244,0.0);">doing</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(244,50,244,0.0);">it</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(244,50,244,0.0);">%uh</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(244,50,244,0.0);">last</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(244,50,244,0.0);">week</span><br/><br/><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(244,50,244,1.0);">Xiulian</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(244,50,244,1.0);">Gu</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(244,50,244,0.0);">,</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(244,50,244,0.0);">minister</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(244,50,244,0.0);">of</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(244,50,244,0.0);">the</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(244,50,244,0.0);">Chemi ...

# %%
bg_color = get_color()
display(HTML(get_colored_results_html(tokens_test_sim['centroid'][:10], calc_sim_min_max(sim_list_test['centroid'][:10]), bg_color)))
# Out:
# <div style="line-height: 1.5em;"><h3 style="margin-bottom:0.3em;">Visualization of tokens to NE similarities on test set</h3><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.25764473389073506);">The</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.20809644404813338);">singer</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.2015157170413745);">was</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.23899355228498495);">brother</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.2646375775879729);">Jermaine</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.17583298321180862);">,</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.2149659653113929);">and</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.145368466996779);">the</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.12932921043228648);">claims</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.13019505306231277);">based</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.12181982624775199);">on</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.14767276794547182);">the</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.04148198761082809);">projected</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.06358188859880981);">outline</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.10978495453343473);">for</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.13733022059314984);">his</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.032972860014274574);">abandoned</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.1718968169967264);">``</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.0841552340209838);">tell</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.17098306359693374);">-</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.048120246270077556);">all</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.17333011626589598);">''</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.12959949398836623);">family</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.14333286737001164);">story</span><br/><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.14742516957853488);">.</span><br/><br/><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.2412619507740121);">As</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.4519673050255054);">Greg</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.48174859588237967);">Lefevre</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.19926545490293426);">reports</span><span style="padding: 0.15em; margin-right: 4px; border-rad ...

# %%
display(HTML(get_colored_results_html(tokens_test_sim['nearest'][:10], calc_sim_min_max(sim_list_test['nearest'][:10]), bg_color)))
# Out:
# <div style="line-height: 1.5em;"><h3 style="margin-bottom:0.3em;">Visualization of tokens to NE similarities on test set</h3><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.1872320715252531);">The</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.16138048633190935);">singer</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.28268144236769327);">was</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.14749994311544198);">brother</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.24122760186031356);">Jermaine</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.4981455007514405);">,</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.2545805552277804);">and</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.10496013357949015);">the</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.11194390636612117);">claims</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.1162369306107778);">based</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.1714307848526635);">on</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.14471499027383908);">the</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.0730838902259425);">projected</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.08598312572848096);">outline</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.2322665040572645);">for</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.11623996706180367);">his</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.013695718615437662);">abandoned</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.0883365226904453);">``</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.056461260758885363);">tell</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.865899143196507);">-</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.09932696264190022);">all</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.19019843220604932);">''</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.11834835069367941);">family</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.1731607855082431);">story</span><br/><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.2642441429640251);">.</span><br/><br/><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.22553069872776824);">As</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.4140914059494049);">Greg</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.4351761204936412);">Lefevre</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.1948808446002373);">reports</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0 ...

# %% [markdown]
# ### Plot histograms of test similarities

# %%
# tags_test_bin_flat = np.array(flatten_list(tags2binary(tags_test, symb=False))) # TODO: bag here
# print(np.sum(np.array([1 if t == 1 else 0 for seq in tags2binary(tags_test, symb=False) for t in seq])))
tags_test_bin_flat = np.array([1 if t == 'T' else 0 for seq in tags_test for t in seq])
# dif_tags = set()
# for seq in tags_test:
#     for t in seq:
#         dif_tags.add(t)
# print(dif_tags)
print(tags_test_bin_flat.shape)
print(np.sum(tags_test_bin_flat))
sim_test_words = {}
sim_test_ne = {}
plt.figure(figsize=(12,5))
for i, method in enumerate(['centroid', 'nearest']):
    sim_flat = np.array(flatten_sim(sim_list_test[method])['cosine'])
    sim_test_words[method] = sim_flat[tags_test_bin_flat == 0]
    sim_test_ne[method] = sim_flat[tags_test_bin_flat == 1]
    print(sim_test_words[method].shape)
    print(sim_test_ne[method].shape)
    plt.subplot(1, 2, i+1, title=method)
    plt.hist(sim_test_words[method], normed=True, color = 'green', edgecolor = 'black',
         bins = 30, label='words', fc=(0, 1, 0, 0.3))
    plt.hist(sim_test_ne[method], normed=True, color = 'red', edgecolor = 'black',
             bins = 30, label='named entities', fc=(1, 0, 0, 0.3))
    plt.legend()
# Out:
# (2676,)
# 231
# (2445,)
# (231,)
# /home/kostrovskiy/prog/AI/NLP/DeepPavlov/env/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 2018-08-14 17:28:51.34 DEBUG in 'matplotlib.font_manager'['font_manager'] at line 1343: findfont: Matching :family=sans-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0 to DejaVu Sans ('/home/kostrovskiy/anaconda3/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf') with score of 0.050000
# (2445,)
# (231,)
# 2018-08-14 17:28:51.154 DEBUG in 'matplotlib.font_manager'['font_manager'] at line 1343: findfont: Matching :family=sans-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=12.0 to DejaVu Sans ('/home/kostrovskiy/anaconda3/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf') with score of 0.050000

# %% [markdown]
# ### Plot probability densities

# %%
# https://stackoverflow.com/questions/15415455/plotting-probability-density-function-by-sample-with-matplotlib
from scipy.stats.kde import gaussian_kde
from numpy import linspace
plt.figure(figsize=(12,5))
for i, method in enumerate(['centroid', 'nearest']):
    kde_words = gaussian_kde( sim_test_words[method] )
    dist_space_words = linspace( min(sim_test_words[method]), max(sim_test_words[method]), 100 )
    kde_ne = gaussian_kde( sim_test_ne[method] )
    dist_space_ne = linspace( min(sim_test_ne[method]), max(sim_test_ne[method]), 100 )
    plt.subplot(1, 2, i+1, title=method)
    plt.plot( dist_space_words, kde_words(dist_space_words), color='green', label='words' )
    plt.plot( dist_space_ne, kde_ne(dist_space_ne), color='red',  label='named entities' )
    plt.legend(loc='upper right')
    plt.grid()
#     plt.title('Probability densities')

# %% [markdown]
# ### F1 score

# %%
def infer_tags(sim_list, sim_type, T=0.5, threshold=0.5):
    sim_min, sim_max = calc_sim_min_max(sim_list)
    tokens_length = get_tokens_len(sim_list)
    tags = [['T' if sim_transform(sim_list[i][j][sim_type], sim_min, sim_max, T)  > threshold else 'O' for j in range(tokens_length[i])] for i in range(len(tokens_length))]
    return tags

# %%
from sklearn.metrics import f1_score
f1 = {}
for i, method in enumerate(['centroid', 'nearest']):
    sim_list = sim_list_test[method]  
    tags_test_pred = infer_tags(sim_list, 'cosine', T=1, threshold=0.5)
#     target = flatten_list(tags2binary(tags_test, symb=False))
#     pred = flatten_list(tags2binary(tags_test_pred, symb=False))
    target = [1 if t == 'T' else 0 for seq in tags_test for t in seq]
    pred = [1 if t == 'T' else 0 for seq in tags_test_pred for t in seq]
#     print(sum(target))
#     print(sum(pred))
    f1[method] = f1_score(target, pred)
print('F1 scores:')
for k in f1.keys():
    print('{}: {:3f}'.format(k, f1[k]))
# Out:
# F1 scores:
# centroid: 0.814458
# nearest: 0.322148

# %%
print('+++++ Samples stats +++++')
print('Support set:')
print_data_props(calc_data_props(tokens_train,tags_train))
print('Tests:')
print_data_props(calc_data_props(tokens_test,tags_test))
# Out:
# +++++ Samples stats +++++
# Support set:
# #sentences = 10, #tokens = 318, #ne = 21, #ne / #tokens = 0.066,
# Tests:
# #sentences = 100, #tokens = 2676, #ne = 231, #ne / #tokens = 0.086,

# %%
print(np.sum(np.array([1 if t == 'T' else 0 for seq in tags_test for t in seq])))
# Out:
# 231

# %% [markdown]
# ### Try SVM

# %%
def get_tokens_count(tokens:list):
    return len([t for seq in tokens for t in seq])
def embeddings2feat_mat(embeddings:np.ndarray, tokens_length):
    n_tokens = sum(tokens_length)
    n_features = embeddings.shape[-1]
    feat_mat = np.zeros((n_tokens, n_features))
#     print(feat_mat.shape)
    k = 0
    for i in range(len(tokens_length)):
        for j in range(tokens_length[i]):
            feat_mat[k, :] = embeddings[i, j, :]
            k += 1           
    return feat_mat

# %%
from sklearn.svm import SVC
X_train = embeddings2feat_mat(embeddings_support, get_tokens_len(tokens_train))
y_train = np.array([1 if t == 'T' else 0 for seq in tags_train for t in seq])
# print(np.bincount(y_train))
n_ne = sum(y_train)
n_words = y_train.size - sum(y_train)
n_tokens = n_ne + n_words
weights = [n_tokens/(2*n_ne) if label == 1 else n_tokens/(2*n_words) for label in y_train]
print(n_ne)
print(n_words)
# print(np.unique(weights))
clf = SVC(probability=True, kernel='sigmoid')
clf.fit(X_train, y_train, weights)
X_test = embeddings2feat_mat(embeddings_test, get_tokens_len(tokens_test))
y_test = np.array([1 if t == 'T' else 0 for seq in tags_test for t in seq])
pred = clf.predict(X_test)
print(sum(pred))
print(clf.score(X_test, y_test))
print('F1 score: {}'.format(f1_score(y_test, pred)))
# print(clf.decision_function(X_test))
# print(np.min(clf.decision_function(X_test)))
# print(np.max(clf.decision_function(X_test)))
sim_list = clf.predict_proba(X_test)[:,1]
print(np.max(sim_list))
# Out:
# 21
# 297
# 230
# 0.9794469357249627
# F1 score: 0.8806941431670282
# 0.9901473775277589

# %%
def zip_tokens_sim_list(tokens, sim_list):
    tokens_sim = []
    k = 0
    print(len(sim_list.shape))
    for seq in tokens:
        tokens_sim.append([])
        for t in seq:
            tokens_sim[-1].append((t, sim_list[k]))
            k += 1
    return tokens_sim

# %%
display(HTML(get_colored_results_html(zip_tokens_sim_list(tokens_test, sim_list), None, bg_color, T=1)))

# %%
sim_words = sim_list[y_test == 0]
sim_ne = sim_list[y_test == 1]
print(np.min(sim_ne))
print(np.max(sim_ne))
print(sim_words.shape)
print(sim_ne.shape)
kde_words = gaussian_kde(sim_words)
dist_space_words = linspace( min(sim_words), max(sim_words), 1000 )
kde_ne = gaussian_kde(sim_ne)
dist_space_ne = linspace( min(sim_ne), max(sim_ne), 1000 )
plt.plot( dist_space_words, kde_words(dist_space_words), color='green', label='words' )
plt.plot( dist_space_ne, kde_ne(dist_space_ne), color='red',  label='named entities' )
plt.legend(loc='upper right')
plt.grid()
# Out:
# 0.002869536589683754
# 0.9901473775277589
# (2445,)
# (231,)

# %% [markdown]
# ### Weighted kNN

# %%
import sys
from math import ceil, floor
def calc_weighted_kNN(X_train, y_train, X_test, y_test=None, k=1, metric='dot_prod', use_class_weights=True, use_sim_weights=True):
    # Weights for classes
    n_classes = np.unique(y_train).size
    n_train_samples = y_train.size
    class_weights = np.array([1,1])
    if use_class_weights:
        class_weights = n_train_samples/(n_classes*np.bincount(y_train))
#     print(np.bincount(y_train))
#     print(n_classes)
#     print(weights)
    n_test_samples = X_test.shape[0]
    probas = np.zeros((n_test_samples))
    pred = np.zeros((n_test_samples), dtype=np.int64)
    # Find k nearest neighbours for each test sample
    for idx_test in range(n_test_samples):
        x = X_test[idx_test,:]
        top_k_sim = np.zeros((k))
        top_k_sim.fill(np.NINF)
        top_k_labels = np.zeros((k), dtype=np.int64)
        for idx_train in range(n_train_samples):
            sim = calc_sim(x, X_train[idx_train, :])[metric]
            for i, sim_from_top in enumerate(top_k_sim):
                if sim > sim_from_top:
                    top_k_sim[i] = sim
                    top_k_labels[i] = y_train[idx_train]
                    break
#         print(top_k_sim)
#         print(top_k_labels)
        calc_prob_dist = lambda ar: ar/(np.sum(ar))
        n_labels_c1 = np.sum(top_k_labels.astype(np.int64))
        n_labels_c0 = top_k_labels.size - n_labels_c1
        if use_sim_weights:
            n_labels_c1 = top_k_sim[top_k_labels == 1].dot(np.ones((n_labels_c1)))
            n_labels_c0 = top_k_sim[top_k_labels == 0].dot(np.ones((n_labels_c0)))
        bincount = np.array([n_labels_c0, n_labels_c1])
#         print(bincount)
        prob_cur = calc_prob_dist(class_weights*bincount)
#         print(prob_cur)
        probas[idx_test] = prob_cur[1]
        pred[idx_test] = 1 if prob_cur[1] > prob_cur[0] else 0
#         print(pred[idx_test])
        # https://stackoverflow.com/questions/3002085/python-to-print-out-status-bar-and-percentage
        sys.stdout.write('\r')
        progress = idx_test/X_test.shape[0]
        sys.stdout.write("[%-20s] %d%%" % ('='*int(ceil(progress*20)), ceil(progress*100)))
        sys.stdout.flush()
#         print(prob_cur)
#     print(probas)
    return pred, probas

# %%
pred, probas = calc_weighted_kNN(X_train, y_train, X_test, y_test=None, k=1, metric='dot_prod', use_class_weights=False, use_sim_weights=True)
# Out:
# [====================] 100%

# %%
print('F1 score: {}'.format(f1_score(y_test, pred)))
print(np.sum(pred))
# Out:
# F1 score: 0.8711656441717791
# 258

# %%
display(HTML(get_colored_results_html(zip_tokens_sim_list(tokens_test, probas), None, bg_color, T=1)))
# Out:
# 1
# <div style="line-height: 1.5em;"><h3 style="margin-bottom:0.3em;">Visualization of tokens to NE similarities on test set</h3><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.0);">The</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.0);">singer</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.0);">was</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.0);">brother</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,1.0);">Jermaine</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.0);">,</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.0);">and</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.0);">the</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.0);">claims</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.0);">based</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.0);">on</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.0);">the</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.0);">projected</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.0);">outline</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.0);">for</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.0);">his</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.0);">abandoned</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.0);">``</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.0);">tell</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.0);">-</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.0);">all</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.0);">''</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.0);">family</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.0);">story</span><br/><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.0);">.</span><br/><br/><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.0);">As</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,1.0);">Greg</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,1.0);">Lefevre</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.0);">reports</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.0);">,</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.0);">many</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.0);">stores</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.0);">have</span><span style="padding: 0.15em; margin-right: 4px; border-r ...

# %%
sim_words = probas[y_test == 0]
sim_ne = probas[y_test == 1]
print(np.min(sim_ne))
print(np.max(sim_ne))
print(sim_words.shape)
print(sim_ne.shape)
kde_words = gaussian_kde(sim_words)
dist_space_words = linspace( min(sim_words), max(sim_words), 1000 )
kde_ne = gaussian_kde(sim_ne)
dist_space_ne = linspace( min(sim_ne), max(sim_ne), 1000 )
plt.plot( dist_space_words, kde_words(dist_space_words), color='green', label='words' )
plt.plot( dist_space_ne, kde_ne(dist_space_ne), color='red',  label='named entities' )
plt.legend(loc='upper right')
plt.grid()
# Out:
# 0.0
# 1.0
# (2445,)
# (231,)

# %% [markdown]
# ### Centroid for NE and kNN for words

# %%
def softmax(ar, scale=True):
    ar = ar[:]
    eps = 1e-10
    if scale:
        ar_min = np.min(ar)
        ar_max = np.max(ar)
        if abs(ar_max - ar_min) > eps:
            ar = (ar - ar_min)/(ar_max - ar_min)
    return np.exp(ar)/(np.sum(np.exp(ar)))

def calc_centroid_kNN(X_train, y_train, X_test, y_test=None, k=5, metric='cosine', use_class_weights=True):
    # Weights for classes
    n_classes = np.unique(y_train).size
    n_train_samples = y_train.size
    class_weights = np.array([1,1])
    if use_class_weights:
        class_weights = n_train_samples/(n_classes*np.bincount(y_train))

    # Centroid for class 1 examples
    centroid_c1 = np.mean(X_train[y_train == 1, :], axis=0)
#     print(centroid_c1.shape)
    
    n_test_samples = X_test.shape[0]
    probas = np.zeros((n_test_samples))
    pred = np.zeros((n_test_samples), dtype=np.int64)
    # Find k nearest neighbours of class 0 for each test sample
    for idx_test in range(n_test_samples):
        x = X_test[idx_test,:]
        sim_c1 = calc_sim(x, centroid_c1)[metric]
        top_k_sim = np.zeros((k))
        top_k_sim.fill(np.NINF)
        for _, example_c0 in enumerate(X_train[y_train == 0, :]):
            sim = calc_sim(x, example_c0)[metric]
            for i, sim_from_top in enumerate(top_k_sim):
                if sim > sim_from_top:
                    top_k_sim[i] = sim
                    break
#         print(top_k_sim)
#         print(top_k_labels)
        sim_c0 = np.mean(top_k_sim)
#         print(sim_c0)
#         print(sim_c1)
        prob_cur = softmax(class_weights*np.array([sim_c0, sim_c1]))
#         print(prob_cur)
        probas[idx_test] = prob_cur[1]
        pred[idx_test] = 1 if prob_cur[1] > prob_cur[0] else 0
#         print(pred[idx_test])
        # https://stackoverflow.com/questions/3002085/python-to-print-out-status-bar-and-percentage
        sys.stdout.write('\r')
        progress = idx_test/X_test.shape[0]
        sys.stdout.write("[%-20s] %d%%" % ('='*int(ceil(progress*20)), ceil(progress*100)))
        sys.stdout.flush()
#         print(prob_cur)
#     print(probas)
    return pred, probas

# %%
pred, probas = calc_centroid_kNN(X_train, y_train, X_test, y_test=None, k=1, metric='cosine', use_class_weights=False)
# Out:
# [====================] 100%

# %%
print('F1 score: {}'.format(f1_score(y_test, pred)))
print('#class 1 predictions = {}'.format(np.sum(pred)))
# Out:
# F1 score: 0.8765432098765432
# #class 1 predictions = 255

# %%
display(HTML(get_colored_results_html(zip_tokens_sim_list(tokens_test, probas), None, bg_color, T=1)))
# Out:
# 1
# <div style="line-height: 1.5em;"><h3 style="margin-bottom:0.3em;">Visualization of tokens to NE similarities on test set</h3><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.2689414213699951);">The</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.2689414213699951);">singer</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.2689414213699951);">was</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.2689414213699951);">brother</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.7310585786300049);">Jermaine</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.2689414213699951);">,</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.2689414213699951);">and</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.2689414213699951);">the</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.2689414213699951);">claims</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.2689414213699951);">based</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.2689414213699951);">on</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.2689414213699951);">the</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.2689414213699951);">projected</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.2689414213699951);">outline</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.2689414213699951);">for</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.2689414213699951);">his</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.2689414213699951);">abandoned</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.2689414213699951);">``</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.2689414213699951);">tell</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.2689414213699951);">-</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.2689414213699951);">all</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.2689414213699951);">''</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.2689414213699951);">family</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.2689414213699951);">story</span><br/><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.2689414213699951);">.</span><br/><br/><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.2689414213699951);">As</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.7310585786300049);">Greg</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.7310585786300049);">Lefevre</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; background: rgba(0,255,0,0.2689414213699951);">reports</span><span style="padding: 0.15em; margin-right: 4px; border-radius: 0.25em; backgroun ...

# %% [markdown]
# ### Clear memory

# %%
# del embeddings_support
# del embeddings_test
